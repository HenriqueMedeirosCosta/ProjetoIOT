# %%
! pip install faker
# Out:
# Requirement already satisfied: faker in /opt/conda/lib/python3.10/site-packages (30.6.0)
# Requirement already satisfied: python-dateutil>=2.4 in /opt/conda/lib/python3.10/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.4->faker) (1.16.0)

# %%
import asyncio
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import random
import string
from faker import Faker
from datetime import datetime
import io
import nest_asyncio
from google.cloud import storage
from google.oauth2 import service_account
from concurrent.futures import ThreadPoolExecutor

# Helper function to generate random IDs
def id_generator(size=6, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.SystemRandom().choice(string.ascii_lowercase + string.digits) for _ in range(size))

# Generate project IDs
projects = [f"{id_generator(4)}" for _ in range(4)]

# Generate tenant IDs
Faker.seed(100)
fake = Faker()
tenants = [id_generator(4) for _ in range(10)]

events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]

# GCP configuration
gcp_bucket_name = "myfirstproject-inputbucket"
gcp_credentials_path = "double-balm-438113-f5-53067ace2784.json"

nest_asyncio.apply()

# Define schema (same as before)
humidity_schema = pa.struct([
    ('temperature', pa.float64()),
    ('relativeHumidity', pa.float64()),
    ('updateTime', pa.timestamp('ms'))
])

event_data_schema = pa.struct([
    ('humidity', humidity_schema)
])

event_schema = pa.struct([
    ('eventId', pa.string()),
    ('targetName', pa.string()),
    ('eventType', pa.string()),
    ('data', event_data_schema),
    ('timestamp', pa.timestamp('ms'))
])

metadata_schema = pa.struct([
    ('deviceId', pa.string()),
    ('projectId', pa.string()),
    ('deviceType', pa.string()),
    ('productNumber', pa.string())
])

data_schema = pa.struct([
    ('event', event_schema),
    ('metadata', metadata_schema)
])

schema = pa.schema([
    ('day', pa.int64()),
    ('month', pa.int64()),
    ('year', pa.int64()),
    ('tenantId', pa.string()),
    ('eventType', pa.string()),
    ('eventId', pa.string()),
    ('data', data_schema)
])

def upload_to_gcs(bucket, blob_name, data):
    blob = bucket.blob(blob_name)
    blob.upload_from_string(data)
    print(f'Successfully uploaded file to GCS: {blob_name}')

async def generate_and_upload_data(i, bucket, executor):
    # Generate sample data (same as before)
    day = fake.day_of_month()
    month = fake.month()
    year = fake.year()
    tenantId = random.choice(tenants)
    project = random.choice(projects)
    eventType = random.choice(events)
    eventId = f"{tenantId}_{id_generator(4)}"
    update_time = fake.date_time_this_year()
    
    sample_json_data = [{
        "day": day,
        "month": month,
        "year": year,
        "tenantId": tenantId,
        "eventType": eventType,
        "eventId": eventId,
        "data": {
            "event": {
                "eventId": eventId,
                "targetName": f"projects/{project}/devices/{eventId}adg",
                "eventType": eventType,
                "data": {
                    "humidity": {
                        "temperature": round(random.uniform(10.0, 40.0), 2),
                        "relativeHumidity": round(random.uniform(30.0, 70.0), 2),
                        "updateTime": update_time
                    }
                },
                "timestamp": update_time
            },
            "metadata": {
                "deviceId": f"{eventId}adg",
                "projectId": project,
                "deviceType": eventType,
                "productNumber": "102081"
            }
        }
    }]
    
    df = pd.DataFrame(sample_json_data)
    df['day'] = df['day'].astype('int64')
    df['month'] = df['month'].astype('int64')
    df['year'] = df['year'].astype('int64')

    table = pa.Table.from_pandas(df, schema=schema)
    
    try:
        with io.BytesIO() as f:
            pq.write_table(table, f, coerce_timestamps='ms')
            f.seek(0)
            blob_name = f"{eventId}_.parquet"
            # Use ThreadPoolExecutor to run the upload in a separate thread
            await asyncio.get_event_loop().run_in_executor(
                executor, upload_to_gcs, bucket, blob_name, f.getvalue())
    except Exception as e:
        print(f'Error on iteration {i}: {e}')

async def main():
    n_rows = 3  # Number of rows
    
    # Set up GCP credentials and client
    credentials = service_account.Credentials.from_service_account_file(gcp_credentials_path)
    storage_client = storage.Client(credentials=credentials)
    bucket = storage_client.bucket(gcp_bucket_name)
    
    # Create a ThreadPoolExecutor for running GCS uploads
    with ThreadPoolExecutor(max_workers=10) as executor:
        tasks = [asyncio.ensure_future(generate_and_upload_data(i, bucket, executor)) for i in range(n_rows)]
        await asyncio.gather(*tasks)

# Run the main coroutine
if __name__ == "__main__":
    before = datetime.now()
    print("Start time:", before)

    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())

    after = datetime.now()
    print("End time:", after)
    print("Elapsed time:", after - before)
# Out:
# Start time: 2024-10-18 08:28:42.700483
# Successfully uploaded file to GCS: yk53_av8o_.parquet
# Successfully uploaded file to GCS: i1qp_3mdc_.parquet
# Successfully uploaded file to GCS: 8j9f_c4hd_.parquet
# End time: 2024-10-18 08:28:43.941967
# Elapsed time: 0:00:01.241484

# %%
import asyncio
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import random
import string
from faker import Faker
from datetime import datetime
import io
import nest_asyncio
from google.cloud import storage
from google.oauth2 import service_account
from concurrent.futures import ThreadPoolExecutor

# Helper function to generate random IDs
def id_generator(size=11, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.SystemRandom().choice(string.ascii_lowercase + string.digits) for _ in range(size))

# Generate project IDs
projects = [f"{id_generator(4)}" for _ in range(4)]

# Generate tenant IDs
Faker.seed(100)
fake = Faker()
tenants = [id_generator(4) for _ in range(10)]

events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]

# GCP configuration
gcp_bucket_name = "myfirstproject-inputbucket"
gcp_credentials_path = "double-balm-438113-f5-53067ace2784.json"  # Atualize com o caminho correto

nest_asyncio.apply()

# Define schema
schema = pa.schema([
    ('day', pa.int64()),
    ('month', pa.int64()),
    ('year', pa.int64()),
    ('tenantId', pa.string()),
    ('eventType', pa.string()),
    ('eventId', pa.string()),
    ('data', pa.struct([
        ('Fornecedor', pa.struct([
            ('Nome_Fazenda', pa.string()),
            ('Proprietario', pa.string()),
            ('CNPJ_CPF', pa.string()),
            ('Endereco', pa.string()),
            ('Telefone', pa.string()),
            ('Email', pa.string())
        ])),
        ('MateriaPrima', pa.struct([
            ('Tipo_MateriaPrima', pa.string()),
            ('Quantidade_Recebida', pa.float64()),
            ('Data_Recebimento', pa.timestamp('ms')),
            ('Qualidade', pa.string())  # Alterado para string
        ])),
        ('Produto', pa.struct([
            ('Nome_Produto', pa.string()),
            ('Categoria', pa.string()),
            ('Descricao', pa.string()),
            ('Unidade_Medida', pa.string()),
            ('Preco_Unitario', pa.float64()),
            ('Prazo_Validade', pa.int64())
        ])),
        ('Funcionario', pa.struct([
            ('Nome', pa.string()),
            ('Cargo', pa.string()),
            ('Departamento', pa.string()),
            ('Data_Contratacao', pa.timestamp('ms')),
            ('Salario', pa.float64()),
            ('Contato_Emergencia', pa.string())
        ]))
    ]))
])

equipamentos_laticinios = [
    "Tanques de recepção e armazenamento de leite cru",
    "Sistemas de filtração e clarificação",
    "Pasteurizadores (placas ou tubulares)",
    "Homogeneizadores",
    "Tanques de processamento UHT",
    "Fermentadores para iogurte",
    "Tanques de cultura para queijos",
    "Prensas para queijo",
    "Formas para queijo",
    "Batedeiras para manteiga",
    "Desnatadeiras",
    "Tanques de maturação para queijos",
    "Câmaras de maturação para queijos",
    "Equipamentos de corte e moldagem de queijos",
    "Embaladoras para diversos produtos",
    "Tanques de mistura para bebidas lácteas",
    "Sistemas CIP (Clean-in-Place)",
    "Caldeiras para geração de vapor",
    "Torres de resfriamento",
    "Compressores de ar",
    "Sistemas de refrigeração",
    "Bombas centrífugas sanitárias",
    "Trocadores de calor",
    "Evaporadores (para produção de leite condensado e creme de leite)",
    "Tanques de cristalização (para requeijão)",
    "Sistemas de automação e controle",
    "Equipamentos de laboratório para controle de qualidade",
    "Esteiras transportadoras",
    "Empilhadeiras",
    "Câmaras frias para armazenamento de produtos acabados"
]

def upload_to_gcs(bucket, blob_name, data):
    blob = bucket.blob(blob_name)
    blob.upload_from_string(data)
    print(f'Successfully uploaded file to GCS: {blob_name}')

async def generate_and_upload_data(i, bucket, executor):
    day = fake.day_of_month()
    month = fake.month()
    year = fake.year()
    tenantId = random.choice(tenants)
    project = random.choice(projects)
    eventType = random.choice(events)
    eventId = f"{tenantId}_{id_generator(4)}"
    update_time = fake.date_time_this_year()
    
    sample_json_data = [{
        "day": day,
        "month": month,
        "year": year,
        "tenantId": tenantId,
        "eventType": eventType,
        "eventId": eventId,
        "data": {
            "Fornecedor": {
                "Nome_Fazenda": fake.company(),
                "Proprietario": fake.name(),
                "CNPJ_CPF": id_generator(),
                "Endereco": fake.address(),
                "Telefone": fake.phone_number(),
                "Email": fake.email()
            },
            "MateriaPrima": {
                "Tipo_MateriaPrima": "Leite",
                "Quantidade_Recebida": round(random.uniform(1000.0, 5000.0), 2),
                "Data_Recebimento": update_time,
                "Qualidade": '{"acidez": 0.12, "bacterias": 250}'  # Exemplo de JSON
            },
            "Produto": {
                "Nome_Produto": "Leite Integral",
                "Categoria": "Laticínios",
                "Descricao": "Leite integral fresco.",
                "Unidade_Medida": "litro",
                "Preco_Unitario": round(random.uniform(2.0, 5.0), 2),
                "Prazo_Validade": random.randint(5, 30)
            },
            "Funcionario": {
                "Nome": fake.name(),
                "Cargo": "Operador",
                "Departamento": "Produção",
                "Data_Contratacao": update_time,
                "Salario": round(random.uniform(2000.0, 5000.0), 2),
                "Contato_Emergencia": fake.name() + ", " + fake.phone_number()
            },
            "equipamento": {
                "id_equipamento": id_generator(7),
                "nome_equipamento": random.choice(equipamentos_laticinios),
                "data_aquisicao": update_time
            }
        }
    }]
    
    df = pd.DataFrame(sample_json_data)
    df['day'] = df['day'].astype('int64')
    df['month'] = df['month'].astype('int64')
    df['year'] = df['year'].astype('int64')

    table = pa.Table.from_pandas(df, schema=schema)
    
    try:
        with io.BytesIO() as f:
            pq.write_table(table, f, coerce_timestamps='ms')
            f.seek(0)
            blob_name = f"{eventId}_.parquet"
            await asyncio.get_event_loop().run_in_executor(
                executor, upload_to_gcs, bucket, blob_name, f.getvalue())
    except Exception as e:
        print(f'Error on iteration {i}: {e}')

async def main():
    n_rows = 3  # Number of rows
    
    credentials = service_account.Credentials.from_service_account_file(gcp_credentials_path)
    storage_client = storage.Client(credentials=credentials)
    bucket = storage_client.bucket(gcp_bucket_name)
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        tasks = [asyncio.ensure_future(generate_and_upload_data(i, bucket, executor)) for i in range(n_rows)]
        await asyncio.gather(*tasks)

# Run the main coroutine
if __name__ == "__main__":
    before = datetime.now()
    print("Start time:", before)

    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())

    after = datetime.now()
    print("End time:", after)
    print("Elapsed time:", after - before)
# Out:
# Start time: 2024-10-18 21:34:57.512159
# Successfully uploaded file to GCS: 0grd_nhvq_.parquet
# Successfully uploaded file to GCS: 3hxl_j2wz_.parquet
# Successfully uploaded file to GCS: m53r_mayt_.parquet
# End time: 2024-10-18 21:34:58.744331
# Elapsed time: 0:00:01.232172

# %%
import asyncio
import pandas as pd
import random
import string
from faker import Faker
from datetime import datetime
import nest_asyncio
from google.cloud import storage
from google.oauth2 import service_account
from concurrent.futures import ThreadPoolExecutor
import json

# Helper function to generate random IDs
def id_generator(size=11, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.SystemRandom().choice(string.ascii_lowercase + string.digits) for _ in range(size))

# Generate project IDs
projects = [f"{id_generator(4)}" for _ in range(4)]

# Generate tenant IDs
Faker.seed(100)
fake = Faker()
tenants = [id_generator(4) for _ in range(10)]

events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]

# GCP configuration
gcp_bucket_name = "myfirstproject-inputbucket"
gcp_credentials_path = "double-balm-438113-f5-53067ace2784.json"  # Atualize com o caminho correto

nest_asyncio.apply()

equipamentos_laticinios = [
    "Tanques de recepção e armazenamento de leite cru",
    "Sistemas de filtração e clarificação",
    "Pasteurizadores (placas ou tubulares)",
    "Homogeneizadores",
    "Tanques de processamento UHT",
    "Fermentadores para iogurte",
    "Tanques de cultura para queijos",
    "Prensas para queijo",
    "Formas para queijo",
    "Batedeiras para manteiga",
    "Desnatadeiras",
    "Tanques de maturação para queijos",
    "Câmaras de maturação para queijos",
    "Equipamentos de corte e moldagem de queijos",
    "Embaladoras para diversos produtos",
    "Tanques de mistura para bebidas lácteas",
    "Sistemas CIP (Clean-in-Place)",
    "Caldeiras para geração de vapor",
    "Torres de resfriamento",
    "Compressores de ar",
    "Sistemas de refrigeração",
    "Bombas centrífugas sanitárias",
    "Trocadores de calor",
    "Evaporadores (para produção de leite condensado e creme de leite)",
    "Tanques de cristalização (para requeijão)",
    "Sistemas de automação e controle",
    "Equipamentos de laboratório para controle de qualidade",
    "Esteiras transportadoras",
    "Empilhadeiras",
    "Câmaras frias para armazenamento de produtos acabados"
]

def upload_to_gcs(bucket, blob_name, data):
    blob = bucket.blob(blob_name)
    blob.upload_from_string(data)
    print(f'Successfully uploaded file to GCS: {blob_name}')

async def generate_and_upload_data(i, bucket, executor):
    day = fake.day_of_month()
    month = fake.month()
    year = fake.year()
    tenantId = random.choice(tenants)
    project = random.choice(projects)
    eventType = random.choice(events)
    eventId = f"{tenantId}_{id_generator(4)}"
    update_time = fake.date_time_this_year()
    
    evento = {
        "day": day,
        "month": month,
        "year": year,
        "tenantId": tenantId,
        "eventType": eventType,
        "eventId": eventId
    }
    
    fornecedor = {
        "Nome_Fazenda": fake.company(),
        "Proprietario": fake.name(),
        "CNPJ_CPF": id_generator(),
        "Endereco": fake.address(),
        "Telefone": fake.phone_number(),
        "Email": fake.email()
    }
    
    materia_prima = {
        "Tipo_MateriaPrima": "Leite",
        "Quantidade_Recebida": round(random.uniform(1000.0, 5000.0), 2),
        "Data_Recebimento": update_time.isoformat(),
        "Qualidade": json.dumps({"acidez": round(random.uniform(0.1, 0.2), 2), "bacterias": random.randint(200, 300)})
    }
    
    produto = {
        "Nome_Produto": "Leite Integral",
        "Categoria": "Laticínios",
        "Descricao": "Leite integral fresco.",
        "Unidade_Medida": "litro",
        "Preco_Unitario": round(random.uniform(2.0, 5.0), 2),
        "Prazo_Validade": random.randint(5, 30)
    }
    
    funcionario = {
        "Nome": fake.name(),
        "Cargo": "Operador",
        "Departamento": "Produção",
        "Data_Contratacao": update_time.isoformat(),
        "Salario": round(random.uniform(2000.0, 5000.0), 2),
        "Contato_Emergencia": fake.name() + ", " + fake.phone_number()
    }
    
    equipamento = {
        "id_equipamento": id_generator(7),
        "nome_equipamento": random.choice(equipamentos_laticinios),
        "data_aquisicao": update_time.isoformat()
    }
    
    data = {
        "evento": evento,
        "fornecedor": fornecedor,
        "materia_prima": materia_prima,
        "produto": produto,
        "funcionario": funcionario,
        "equipamento": equipamento
    }
    
    try:
        json_data = json.dumps(data)
        blob_name = f"{eventId}_.json"
        await asyncio.get_event_loop().run_in_executor(
            executor, upload_to_gcs, bucket, blob_name, json_data)
    except Exception as e:
        print(f'Error on iteration {i}: {e}')

async def main():
    n_rows = 5  # Number of rows
    
    credentials = service_account.Credentials.from_service_account_file(gcp_credentials_path)
    storage_client = storage.Client(credentials=credentials)
    bucket = storage_client.bucket(gcp_bucket_name)
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        tasks = [asyncio.ensure_future(generate_and_upload_data(i, bucket, executor)) for i in range(n_rows)]
        await asyncio.gather(*tasks)

# Run the main coroutine
if __name__ == "__main__":
    before = datetime.now()
    print("Start time:", before)

    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())

    after = datetime.now()
    print("End time:", after)
    print("Elapsed time:", after - before)
# Out:
# Start time: 2024-10-19 15:43:10.967580
# Successfully uploaded file to GCS: isnf_1mor_.json
# Successfully uploaded file to GCS: s5b6_hlhl_.json
# Successfully uploaded file to GCS: ohre_xwn6_.json
# Successfully uploaded file to GCS: or1g_pu2j_.json
# Successfully uploaded file to GCS: tdjy_xh60_.json
# End time: 2024-10-19 15:43:12.199885
# Elapsed time: 0:00:01.232305

# %%
import asyncio
import pandas as pd
import random
import string
from faker import Faker
from datetime import datetime
import nest_asyncio
from google.cloud import storage
from google.oauth2 import service_account
from concurrent.futures import ThreadPoolExecutor
import pyarrow as pa
import pyarrow.parquet as pq
import json
import io

# Helper function to generate random IDs
def id_generator(size=11, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.SystemRandom().choice(string.ascii_lowercase + string.digits) for _ in range(size))

# Generate project IDs
projects = [f"{id_generator(4)}" for _ in range(4)]

# Generate tenant IDs
Faker.seed(100)
fake = Faker()
tenants = [id_generator(4) for _ in range(10)]

# GCP configuration
gcp_bucket_name = "myfirstproject-inputbucket"
gcp_credentials_path = "double-balm-438113-f5-53067ace2784.json"  # Atualize com o caminho correto

nest_asyncio.apply()

equipamentos_produtos = {
    "Tanques de recepção e armazenamento de leite cru": {
        "produto": "Leite Integral",
        "categoria": "Laticínios",
        "descricao": "Leite integral fresco.",
        "unidade_medida": "litro",
        "preco_unitario": 3.50
    },
    "Fermentadores para iogurte": {
        "produto": "Iogurte Natural",
        "categoria": "Laticínios",
        "descricao": "Iogurte natural fermentado.",
        "unidade_medida": "litro",
        "preco_unitario": 6.00
    },
    "Prensas para queijo": {
        "produto": "Queijo Mussarela",
        "categoria": "Laticínios",
        "descricao": "Queijo mussarela fresco.",
        "unidade_medida": "quilo",
        "preco_unitario": 20.00
    }}
events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]
equipamento_status = ["ativo"] * 8 + ["quebrado", "alerta", "inativo", "manutenção"] * 2

departamentos = [
    "Gestão de Fornecedores",
    "Controle de Matéria-Prima",
    "producao",
    "Gestão de Produtos",
    "Gestão de Estoque",
    "Gestão de Funcionários",
    "Gestão de Equipamentos"]
def upload_to_gcs(bucket, blob_name, data):
    blob = bucket.blob(blob_name)
    blob.upload_from_string(data)
    print(f'Successfully uploaded file to GCS: {blob_name}')

async def generate_and_upload_data(i, bucket, executor):
    day = fake.day_of_month()
    month = fake.month()
    year = fake.year()
    tenantId = random.choice(tenants)
    project = random.choice(projects)
    eventType = random.choice(events)
    eventId = f"{tenantId}_{id_generator(4)}"
    update_time = fake.date_time_this_year()

    # Escolhendo o equipamento e seu produto associado
    equipamento_escolhido = random.choice(list(equipamentos_produtos.keys()))
    produto_info = equipamentos_produtos[equipamento_escolhido]
    status = random.choice(equipamento_status)
    data = {
        
        # Informações sobre o equipamento
        "id_equipamento": [id_generator(7)],
        "nome_equipamento": [equipamento_escolhido],
        "data_aquisicao": [update_time],
        "eqp_status" : [status],
        "eventType": ['NULL' if status in ["quebrado", "inativo"] else random.choice(events)],
        
        "day": [day],
        "month": [month],
        "year": [year],
        "tenantId": [tenantId],
        "eventId": [eventId],
        "Nome_Fazenda": [fake.company()],
        "Proprietario": [fake.name()],
        "CNPJ_CPF": [id_generator()],
        "Endereco": [fake.address()],
        "Telefone": [fake.phone_number()],
        "Email": [fake.email()],
        
        #materia prima
        "Tipo_MateriaPrima": ["Leite"],
        "Quantidade_Recebida": [round(random.uniform(1000.0, 5000.0), 2)],
        "Data_Recebimento": [update_time],
        "Qualidade": [json.dumps({"acidez": round(random.uniform(0.1, 0.2), 2), "bacterias": random.randint(200, 300)})],
        
        # Informações do produto relacionadas ao equipamento
        "Nome_Produto": [produto_info["produto"]],
        "Categoria": [produto_info["categoria"]],
        "Descricao": [produto_info["descricao"]],
        "Unidade_Medida": [produto_info["unidade_medida"]],
        "Preco_Unitario": [produto_info["preco_unitario"]],
        "Prazo_Validade": [random.randint(5, 30)],
        
        #estoque
        
        "quantidade_estoque": [round(random.uniform(0.0, 20000.0), 0)],

        # Informações funcionario
        "Nome_Funcionario": [fake.name()],
        "Cargo": ["Operador"],
        "Departamento": ["Produção"],
        "Data_Contratacao": [update_time],
        "Salario": [round(random.uniform(2000.0, 5000.0), 2)],
        "Contato_Emergencia": [fake.name() + ", " + fake.phone_number()],
        
        # setor
        
        "nome_setor": ["producao"],
        "id_setor": [1]

        
    }

    df = pd.DataFrame(data)
    table = pa.Table.from_pandas(df)
    
    try:
        buffer = io.BytesIO()
        pq.write_table(table, buffer)
        buffer.seek(0)
        blob_name = f"{eventId}_.parquet"
        await asyncio.get_event_loop().run_in_executor(
            executor, upload_to_gcs, bucket, blob_name, buffer.getvalue())
    except Exception as e:
        print(f'Error on iteration {i}: {e}')


async def main():
    n_rows = 50000  # Number of rows
    
    credentials = service_account.Credentials.from_service_account_file(gcp_credentials_path)
    storage_client = storage.Client(credentials=credentials)
    bucket = storage_client.bucket(gcp_bucket_name)
    
    with ThreadPoolExecutor(max_workers=10) as executor:
        tasks = [asyncio.ensure_future(generate_and_upload_data(i, bucket, executor)) for i in range(n_rows)]
        await asyncio.gather(*tasks)

# Run the main coroutine
if __name__ == "__main__":
    before = datetime.now()
    print("Start time:", before)

    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())

    after = datetime.now()
    print("End time:", after)
    print("Elapsed time:", after - before)
# Out:
# Start time: 2024-10-19 22:29:09.858222
# Successfully uploaded file to GCS: k1es_ali6_.parquet
# Successfully uploaded file to GCS: bwfg_qqzy_.parquet
# Successfully uploaded file to GCS: n4vi_3c8d_.parquet
# Successfully uploaded file to GCS: f02z_xnn3_.parquet
# Successfully uploaded file to GCS: bwfg_uqtt_.parquet
# Successfully uploaded file to GCS: idof_comu_.parquet
# Successfully uploaded file to GCS: hxj7_ykap_.parquet
# Successfully uploaded file to GCS: hxj7_4zlv_.parquet
# Successfully uploaded file to GCS: hxj7_hsfk_.parquet
# Successfully uploaded file to GCS: ou4z_vx7d_.parquet
# Successfully uploaded file to GCS: hxj7_oyzj_.parquet
# Successfully uploaded file to GCS: bwfg_obmz_.parquet
# Successfully uploaded file to GCS: idof_3kpy_.parquet
# Successfully uploaded file to GCS: nuj8_p5zi_.parquet
# Successfully uploaded file to GCS: f02z_qzre_.parquet
# Successfully uploaded file to GCS: nuj8_ru1u_.parquet
# Successfully uploaded file to GCS: hxj7_i5u9_.parquet
# Successfully uploaded file to GCS: k1es_phv6_.parquet
# Successfully uploaded file to GCS: bwfg_b852_.parquet
# Successfully uploaded file to GCS: nuj8_w5xl_.parquet
# Successfully uploaded file to GCS: hxj7_em7w_.parquet
# Successfully uploaded file to GCS: hxj7_n3vm_.parquet
# Successfully uploaded file to GCS: ou4z_3veo_.parquet
# Successfully uploaded file to GCS: ix3a_ouo1_.parquet
# Successfully uploaded file to GCS: n4vi_8s3n_.parquet
# Successfully uploaded file to GCS: idof_f61z_.parquet
# Successfully uploaded file to GCS: ix3a_bwbn_.parquet
# Successfully uploaded file to GCS: bwfg_9x64_.parquet
# Successfully uploaded file to GCS: bwfg_48r5_.parquet
# Successfully uploaded file to GCS: k1es_p51z_.parquet
# Successfully uploaded file to GCS: bwfg_igh5_.parquet
# Successfully uploaded file to GCS: k1es_zzip_.parquet
# Successfully uploaded file to GCS: ou4z_jjl0_.parquet
# Successfully uploaded file to GCS: n4vi_2lgp_.parquet
# Successfully uploaded file to GCS: bwfg_i0h9_.parquet
# Successfully uploaded file to GCS: hxj7_f9a4_.parquet
# Successfully uploaded file to GCS: k1es_3fd0_.parquet
# Successfully uploaded file to GCS: bwfg_bv54_.parquet
# Successfully uploaded file to GCS: nuj8_nba7_.parquet
# Successfully uploaded file to GCS: nuj8_3w51_.parquet
# Successfully uploaded file to GCS: f02z_t2da_.parquet
# Successfully uploaded file to GCS: ou4z_eovk_.parquet
# Successfully uploaded file to GCS: nuj8_m6xs_.parquet
# Successfully uploaded file to GCS: hxj7_8b5l_.parquet
# Successfully uploaded file to GCS: ou4z_1vbw_.parquet
# Successfully uploaded file to GCS: idof_y8dg_.parquet
# Successfully uploaded file to GCS: nuj8_92ap_.parquet
# Successfully uploaded file to GCS: idof_wxcv_.parquet
# Successfully uploaded file to GCS: ou4z_6dz0_.parquet
# Successfully uploaded file to GCS: k1es_igen_.parquet
# Successfully uploaded file to GCS: xq9b_t2it_.parquet
# Successfully uploaded file to GCS: bwfg_86ui_.parquet
# Successfully uploaded file to GCS: hxj7_djrq_.parquet
# Successfully uploaded file to GCS: f02z_wg9v_.parquet
# Successfully uploaded file to GCS: ix3a_cmv5_.parquet
# Successfully uploaded file to GCS: bwfg_z79l_.parquet
# Successfully uploaded file to GCS: ou4z_a25s_.parquet
# Successfully uploaded file to GCS: nuj8_orw8_.parquet
# Successfully uploaded file to GCS: k1es_lz7v_.parquet
# Successfully uploaded file to GCS: hxj7_5luu_.parquet
# Successfully uploaded file to GCS: nuj8_cgvp_.parquet
# Successfully uploaded file to GCS: nuj8_f3zx_.parquet
# Successfully uploaded file to GCS: hxj7_g0em_.parquet
# Successfully uploaded file to GCS: ou4z_8rvp_.parquet
# Successfully uploaded file to GCS: f02z_ap3r_.parquet
# Successfully uploaded file to GCS: hxj7_htp8_.parquet
# Successfully uploaded file to GCS: f02z_2l5l_.parquet
# Successfully uploaded file to GCS: hxj7_st2f_.parquet
# Successfully uploaded file to GCS: nuj8_gu14_.parquet
# Successfully uploaded file to GCS: k1es_x8h3_.parquet
# Successfully uploaded file to GCS: hxj7_motg_.parquet
# Successfully uploaded file to GCS: xq9b_bfcg_.parquet
# Successfully uploaded file to GCS: nuj8_mbpu_.parquet
# Successfully uploaded file to GCS: n4vi_69tf_.parquet
# Successfully uploaded file to GCS: k1es_i4kh_.parquet
# Successfully uploaded file to GCS: f02z_tx31_.parquet
# Successfully uploaded file to GCS: hxj7_1nag_.parquet
# Successfully uploaded file to GCS: ou4z_ok56_.parquet
# Successfully uploaded file to GCS: ix3a_iobn_.parquet
# Successfully uploaded file to GCS: n4vi_omuu_.parquet
# Successfully uploaded file to GCS: ix3a_e09a_.parquet
# Successfully uploaded file to GCS: xq9b_o9s6_.parquet
# Successfully uploaded file to GCS: idof_lpnc_.parquet
# Successfully uploaded file to GCS: ix3a_jfiw_.parquet
# Successfully uploaded file to GCS: ou4z_izzd_.parquet
# Successfully uploaded file to GCS: xq9b_a254_.parquet
# Successfully uploaded file to GCS: xq9b_054i_.parquet
# Successfully uploaded file to GCS: ix3a_mfdp_.parquet
# Successfully uploaded file to GCS: nuj8_aczd_.parquet
# Successfully uploaded file to GCS: bwfg_zof0_.parquet
# Successfully uploaded file to GCS: idof_g8rh_.parquet
# Successfully uploaded file to GCS: ix3a_8u27_.parquet
# Successfully uploaded file to GCS: ou4z_jolz_.parquet
# Successfully uploaded file to GCS: f02z_n7rx_.parquet
# Successfully uploaded file to GCS: n4vi_hlaf_.parquet
# Successfully uploaded file to GCS: ix3a_jwqk_.parquet
# Successfully uploaded file to GCS: ix3a_mqxw_.parquet
# Successfully uploaded file to GCS: nuj8_vc6z_.parquet
# Successfully uploaded file to GCS: k1es_i02l_.parquet
# Successfully uploaded file to GCS: xq9b_ho30_.parquet
# Successfully uploaded file to GCS: f02z_vqcl_.parquet
# Successfully uploaded file to GCS: idof_06ew_.parquet
# Successfully uploaded file to GCS: hxj7_um7y_.parquet
# Successfully uploaded file to GCS: ou4z_vp7u_.parquet
# Successfully uploaded file to GCS: nuj8_dtss_.parquet
# Successfully uploaded file to GCS: f02z_g5sh_.parquet
# Successfully uploaded file to GCS: k1es_ekvn_.parquet
# Successfully uploaded file to GCS: k1es_lyg6_.parquet
# Successfully uploaded file to GCS: idof_5lqp_.parquet
# Successfully uploaded file to GCS: bwfg_0fuu_.parquet
# Successfully uploaded file to GCS: hxj7_1q09_.parquet
# Successfully uploaded file to GCS: xq9b_hmq5_.parquet
# Successfully uploaded file to GCS: n4vi_mx2o_.parquet
# Successfully uploaded file to GCS: ou4z_ptxh_.parquet
# Successfully uploaded file to GCS: bwfg_x0ec_.parquet
# Successfully uploaded file to GCS: nuj8_d5km_.parquet
# Successfully uploaded file to GCS: bwfg_2hus_.parquet
# Successfully uploaded file to GCS: bwfg_i8zw_.parquet
# Successfully uploaded file to GCS: ou4z_xghv_.parquet
# Successfully uploaded file to GCS: bwfg_4vz2_.parquet
# Successfully uploaded file to GCS: k1es_rnpv_.parquet
# Successfully uploaded file to GCS: nuj8_rhju_.parquet
# Successfully uploaded file to GCS: n4vi_ri1i_.parquet
# Successfully uploaded file to GCS: f02z_1sh6_.parquet
# Successfully uploaded file to GCS: hxj7_b5lg_.parquet
# Successfully uploaded file to GCS: bwfg_ifbx_.parquet
# Successfully uploaded file to GCS: hxj7_23pa_.parquet
# Successfully uploaded file to GCS: idof_vpgj_.parquet
# Successfully uploaded file to GCS: ou4z_lbq8_.parquet
# Successfully uploaded file to GCS: hxj7_4nbk_.parquet
# Successfully uploaded file to GCS: hxj7_652p_.parquet
# Successfully uploaded file to GCS: bwfg_0zaf_.parquet
# Successfully uploaded file to GCS: ix3a_jkwi_.parquet
# Successfully uploaded file to GCS: ou4z_eup9_.parquet
# Successfully uploaded file to GCS: hxj7_2miy_.parquet
# Successfully uploaded file to GCS: xq9b_dtek_.parquet
# Successfully uploaded file to GCS: k1es_m4wv_.parquet
# Successfully uploaded file to GCS: ou4z_5t18_.parquet
# Successfully uploaded file to GCS: ix3a_7rlh_.parquet
# Successfully uploaded file to GCS: nuj8_3yiy_.parquet
# Successfully uploaded file to GCS: n4vi_2lar_.parquet
# Successfully uploaded file to GCS: nuj8_m3dh_.parquet
# Successfully uploaded file to GCS: xq9b_cn1s_.parquet
# Successfully uploaded file to GCS: bwfg_wz8k_.parquet
# Successfully uploaded file to GCS: ix3a_26au_.parquet
# Successfully uploaded file to GCS: nuj8_0f44_.parquet
# Successfully uploaded file to GCS: f02z_ymyg_.parquet
# Successfully uploaded file to GCS: f02z_dr36_.parquet
# Successfully uploaded file to GCS: xq9b_vsbx_.parquet
# Successfully uploaded file to GCS: bwfg_rp7e_.parquet
# Successfully uploaded file to GCS: ix3a_i8b4_.parquet
# Successfully uploaded file to GCS: ix3a_hzg9_.parquet
# Successfully uploaded file to GCS: f02z_uw3g_.parquet
# Successfully uploaded file to GCS: xq9b_5s1m_.parquet
# Successfully uploaded file to GCS: nuj8_vagd_.parquet
# Successfully uploaded file to GCS: hxj7_yme4_.parquet
# Successfully uploaded file to GCS: ix3a_xu3z_.parquet
# Successfully uploaded file to GCS: f02z_lkdw_.parquet
# Successfully uploaded file to GCS: f02z_inha_.parquet
# Successfully uploaded file to GCS: ix3a_nwzm_.parquet
# Successfully uploaded file to GCS: idof_jbtz_.parquet
# Successfully uploaded file to GCS: idof_gclj_.parquet
# Successfully uploaded file to GCS: nuj8_1ifa_.parquet
# Successfully uploaded file to GCS: k1es_4fms_.parquet
# Successfully uploaded file to GCS: f02z_5k48_.parquet
# Successfully uploaded file to GCS: nuj8_6txk_.parquet
# Successfully uploaded file to GCS: bwfg_rdbv_.parquet
# Successfully uploaded file to GCS: f02z_e53n_.parquet
# Successfully uploaded file to GCS: nuj8_d7xq_.parquet
# Successfully uploaded file to GCS: bwfg_hocu_.parquet
# Successfully uploaded file to GCS: bwfg_83c4_.parquet
# Successfully uploaded file to GCS: n4vi_o0vt_.parquet
# Successfully uploaded file to GCS: bwfg_5m75_.parquet
# Successfully uploaded file to GCS: ix3a_430h_.parquet
# Successfully uploaded file to GCS: xq9b_c72y_.parquet
# Successfully uploaded file to GCS: n4vi_y8ay_.parquet
# Successfully uploaded file to GCS: ou4z_nl1h_.parquet
# Successfully uploaded file to GCS: f02z_mir4_.parquet
# Successfully uploaded file to GCS: idof_b1th_.parquet
# Successfully uploaded file to GCS: hxj7_16gn_.parquet
# Successfully uploaded file to GCS: ou4z_tnt3_.parquet
# Successfully uploaded file to GCS: k1es_60yi_.parquet
# Successfully uploaded file to GCS: k1es_jz9e_.parquet
# Successfully uploaded file to GCS: xq9b_w2iv_.parquet
# Successfully uploaded file to GCS: ou4z_9ysp_.parquet
# Successfully uploaded file to GCS: ou4z_tcth_.parquet
# Successfully uploaded file to GCS: n4vi_i2dk_.parquet
# Successfully uploaded file to GCS: bwfg_cjh9_.parquet
# Successfully uploaded file to GCS: idof_zu1s_.parquet
# Successfully uploaded file to GCS: bwfg_l7eu_.parquet
# Successfully uploaded file to GCS: ou4z_6zqz_.parquet
# Successfully uploaded file to GCS: ix3a_sprd_.parquet
# Successfully uploaded file to GCS: f02z_nvcw_.parquet
# Successfully uploaded file to GCS: nuj8_os2z_.parquet
# Successfully uploaded file to GCS: nuj8_inqb_.parquet
# Successfully uploaded file to GCS: k1es_vrzk_.parquet
# Successfully uploaded file to GCS: nuj8_mm25_.parquet
# Successfully uploaded file to GCS: idof_flf2_.parquet
# Successfully uploaded file to GCS: xq9b_q8js_.parquet
# Successfully uploaded file to GCS: idof_sq5k_.parquet
# Successfully uploaded file to GCS: bwfg_rv3v_.parquet
# Successfully uploaded file to GCS: bwfg_3aya_.parquet
# Successfully uploaded file to GCS: hxj7_wlxq_.parquet
# Successfully uploaded file to GCS: f02z_gyqn_.parquet
# Successfully uploaded file to GCS: f02z_wt1s_.parquet
# Successfully uploaded file to GCS: ix3a_pepv_.parquet
# Successfully uploaded file to GCS: k1es_2xo8_.parquet
# Successfully uploaded file to GCS: idof_ou0x_.parquet
# Successfully uploaded file to GCS: nuj8_wq4e_.parquet
# Successfully uploaded file to GCS: idof_2fib_.parquet
# Successfully uploaded file to GCS: ix3a_ugrb_.parquet
# Successfully uploaded file to GCS: ou4z_devx_.parquet
# Successfully uploaded file to GCS: xq9b_6ing_.parquet
# Successfully uploaded file to GCS: bwfg_nnge_.parquet
# Successfully uploaded file to GCS: k1es_15u5_.parquet
# Successfully uploaded file to GCS: k1es_q59g_.parquet
# Successfully uploaded file to GCS: n4vi_x9mq_.parquet
# Successfully uploaded file to GCS: k1es_glt5_.parquet
# Successfully uploaded file to GCS: k1es_o61m_.parquet
# Successfully uploaded file to GCS: ou4z_ebfr_.parquet
# Successfully uploaded file to GCS: f02z_gieq_.parquet
# Successfully uploaded file to GCS: xq9b_qh8w_.parquet
# Successfully uploaded file to GCS: f02z_qq6i_.parquet
# Successfully uploaded file to GCS: f02z_vtw7_.parquet
# Successfully uploaded file to GCS: nuj8_ee0n_.parquet
# Successfully uploaded file to GCS: bwfg_nc4x_.parquet
# Successfully uploaded file to GCS: f02z_e2n1_.parquet
# Successfully uploaded file to GCS: hxj7_fiuz_.parquet
# Successfully uploaded file to GCS: xq9b_hnt8_.parquet
# Successfully uploaded file to GCS: f02z_br1o_.parquet
# Successfully uploaded file to GCS: ix3a_nynf_.parquet
# Successfully uploaded file to GCS: k1es_hul2_.parquet
# Successfully uploaded file to GCS: f02z_q18l_.parquet
# Successfully uploaded file to GCS: xq9b_dnb4_.parquet
# Successfully uploaded file to GCS: nuj8_ifra_.parquet
# Successfully uploaded file to GCS: ix3a_snr8_.parquet
# Successfully uploaded file to GCS: n4vi_fs4s_.parquet
# Successfully uploaded file to GCS: bwfg_49mg_.parquet
# Successfully uploaded file to GCS: bwfg_lke5_.parquet
# Successfully uploaded file to GCS: ix3a_sfh8_.parquet
# Successfully uploaded file to GCS: idof_5eab_.parquet
# Successfully uploaded file to GCS: hxj7_pzq4_.parquet
# Successfully uploaded file to GCS: k1es_ct6l_.parquet
# Successfully uploaded file to GCS: n4vi_ji9k_.parquet
# Successfully uploaded file to GCS: hxj7_1zri_.parquet
# Successfully uploaded file to GCS: n4vi_9tmq_.parquet
# Successfully uploaded file to GCS: hxj7_7295_.parquet
# Successfully uploaded file to GCS: xq9b_h3jz_.parquet
# Successfully uploaded file to GCS: bwfg_hw7c_.parquet
# Successfully uploaded file to GCS: idof_64eo_.parquet
# Successfully uploaded file to GCS: nuj8_u7r6_.parquet
# Successfully uploaded file to GCS: xq9b_9h3d_.parquet
# Successfully uploaded file to GCS: hxj7_s0mb_.parquet
# Successfully uploaded file to GCS: xq9b_od2y_.parquet
# Successfully uploaded file to GCS: idof_uzhb_.parquet
# Successfully uploaded file to GCS: f02z_1vkd_.parquet
# Successfully uploaded file to GCS: ix3a_usc8_.parquet
# Successfully uploaded file to GCS: n4vi_b5wa_.parquet
# Successfully uploaded file to GCS: ou4z_rom8_.parquet
# Successfully uploaded file to GCS: idof_nc1t_.parquet
# Successfully uploaded file to GCS: ou4z_jcz5_.parquet
# Successfully uploaded file to GCS: idof_b4i5_.parquet
# Successfully uploaded file to GCS: hxj7_nj0t_.parquet
# Successfully uploaded file to GCS: ou4z_7u04_.parquet
# Successfully uploaded file to GCS: ou4z_bwk5_.parquet
# Successfully uploaded file to GCS: bwfg_rmd2_.parquet
# Successfully uploaded file to GCS: ix3a_fzxj_.parquet
# Successfully uploaded file to GCS: k1es_d2zp_.parquet
# Successfully uploaded file to GCS: hxj7_tp88_.parquet
# Successfully uploaded file to GCS: f02z_n4ef_.parquet
# Successfully uploaded file to GCS: hxj7_aal8_.parquet
# Successfully uploaded file to GCS: nuj8_zr6g_.parquet
# Successfully uploaded file to GCS: idof_hhk6_.parquet
# Successfully uploaded file to GCS: hxj7_4qlu_.parquet
# Successfully uploaded file to GCS: ix3a_qw0l_.parquet
# Successfully uploaded file to GCS: n4vi_xqwf_.parquet
# Successfully uploaded file to GCS: ix3a_ndze_.parquet
# Successfully uploaded file to GCS: ix3a_e4nk_.parquet
# Successfully uploaded file to GCS: nuj8_ulih_.parquet
# Successfully uploaded file to GCS: bwfg_wd5w_.parquet
# Successfully uploaded file to GCS: ou4z_4s2w_.parquet
# Successfully uploaded file to GCS: ou4z_6npm_.parquet
# Successfully uploaded file to GCS: k1es_3lu9_.parquet
# Successfully uploaded file to GCS: nuj8_2izg_.parquet
# Successfully uploaded file to GCS: n4vi_z4is_.parquet
# Successfully uploaded file to GCS: nuj8_f3vo_.parquet
# Successfully uploaded file to GCS: ix3a_z6gm_.parquet
# Successfully uploaded file to GCS: nuj8_2rco_.parquet
# Successfully uploaded file to GCS: f02z_wux6_.parquet
# Successfully uploaded file to GCS: xq9b_z4bl_.parquet
# Successfully uploaded file to GCS: k1es_r7ka_.parquet
# Successfully uploaded file to GCS: idof_24t6_.parquet
# Successfully uploaded file to GCS: n4vi_lau7_.parquet
# Successfully uploaded file to GCS: bwfg_m8z1_.parquet
# Successfully uploaded file to GCS: f02z_emjx_.parquet
# Successfully uploaded file to GCS: f02z_k32r_.parquet
# Successfully uploaded file to GCS: idof_egmv_.parquet
# Successfully uploaded file to GCS: n4vi_f0fw_.parquet
# Successfully uploaded file to GCS: f02z_a31j_.parquet
# Successfully uploaded file to GCS: f02z_yd0q_.parquet
# Successfully uploaded file to GCS: idof_1eu8_.parquet
# Successfully uploaded file to GCS: k1es_kehl_.parquet
# Successfully uploaded file to GCS: ou4z_v9nh_.parquet
# Successfully uploaded file to GCS: n4vi_e9k4_.parquet
# Successfully uploaded file to GCS: nuj8_ttds_.parquet
# Successfully uploaded file to GCS: bwfg_4oam_.parquet
# Successfully uploaded file to GCS: bwfg_w8ml_.parquet
# Successfully uploaded file to GCS: bwfg_ki5d_.parquet
# Successfully uploaded file to GCS: n4vi_yg71_.parquet
# Successfully uploaded file to GCS: k1es_nzvl_.parquet
# Successfully uploaded file to GCS: n4vi_c65c_.parquet
# Successfully uploaded file to GCS: n4vi_ktgx_.parquet
# Successfully uploaded file to GCS: bwfg_a2ka_.parquet
# Successfully uploaded file to GCS: n4vi_ptqo_.parquet
# Successfully uploaded file to GCS: xq9b_0ljx_.parquet
# Successfully uploaded file to GCS: bwfg_602w_.parquet
# Successfully uploaded file to GCS: ix3a_978l_.parquet
# Successfully uploaded file to GCS: nuj8_36i2_.parquet
# Successfully uploaded file to GCS: ix3a_hbqp_.parquet
# Successfully uploaded file to GCS: ou4z_vjrc_.parquet
# Successfully uploaded file to GCS: n4vi_i8zr_.parquet
# Successfully uploaded file to GCS: nuj8_jd70_.parquet
# Successfully uploaded file to GCS: k1es_y8p1_.parquet
# Successfully uploaded file to GCS: n4vi_n9l5_.parquet
# Successfully uploaded file to GCS: ix3a_xa8l_.parquet
# Successfully uploaded file to GCS: ou4z_oox0_.parquet
# Successfully uploaded file to GCS: n4vi_edwa_.parquet
# Successfully uploaded file to GCS: bwfg_9tww_.parquet
# Successfully uploaded file to GCS: nuj8_5bab_.parquet
# Successfully uploaded file to GCS: ix3a_zvg4_.parquet
# Successfully uploaded file to GCS: hxj7_lawe_.parquet
# Successfully uploaded file to GCS: bwfg_d673_.parquet
# Successfully uploaded file to GCS: idof_wrh9_.parquet
# Successfully uploaded file to GCS: k1es_4go4_.parquet
# Successfully uploaded file to GCS: hxj7_0abd_.parquet
# Successfully uploaded file to GCS: k1es_adn6_.parquet
# Successfully uploaded file to GCS: bwfg_e8v6_.parquet
# Successfully uploaded file to GCS: f02z_0goq_.parquet
# Successfully uploaded file to GCS: bwfg_d01j_.parquet
# Successfully uploaded file to GCS: hxj7_7k4j_.parquet
# Successfully uploaded file to GCS: f02z_ibdd_.parquet
# Successfully uploaded file to GCS: ou4z_mgg4_.parquet
# Successfully uploaded file to GCS: n4vi_cwk1_.parquet
# Successfully uploaded file to GCS: n4vi_702v_.parquet
# Successfully uploaded file to GCS: idof_db61_.parquet
# Successfully uploaded file to GCS: nuj8_v9x3_.parquet
# Successfully uploaded file to GCS: ou4z_bhuu_.parquet
# Successfully uploaded file to GCS: k1es_1iu8_.parquet
# Successfully uploaded file to GCS: ou4z_ykbd_.parquet
# Successfully uploaded file to GCS: idof_uoey_.parquet
# Successfully uploaded file to GCS: idof_in2g_.parquet
# Successfully uploaded file to GCS: idof_eiws_.parquet
# Successfully uploaded file to GCS: ix3a_vhup_.parquet
# Successfully uploaded file to GCS: bwfg_j745_.parquet
# Successfully uploaded file to GCS: ix3a_33dl_.parquet
# Successfully uploaded file to GCS: bwfg_rg7u_.parquet
# Successfully uploaded file to GCS: f02z_yp2h_.parquet
# Successfully uploaded file to GCS: f02z_ap0i_.parquet
# Successfully uploaded file to GCS: ix3a_nky5_.parquet
# Successfully uploaded file to GCS: bwfg_mrpr_.parquet
# Successfully uploaded file to GCS: n4vi_zthl_.parquet
# Successfully uploaded file to GCS: idof_c96p_.parquet
# Successfully uploaded file to GCS: n4vi_xd8p_.parquet
# Successfully uploaded file to GCS: hxj7_y7if_.parquet
# Successfully uploaded file to GCS: hxj7_uzxu_.parquet
# Successfully uploaded file to GCS: f02z_nl3h_.parquet
# Successfully uploaded file to GCS: xq9b_3qn3_.parquet
# Successfully uploaded file to GCS: ou4z_p7wy_.parquet
# Successfully uploaded file to GCS: bwfg_8yl1_.parquet
# Successfully uploaded file to GCS: bwfg_wmti_.parquet
# Successfully uploaded file to GCS: ix3a_8a5u_.parquet
# Successfully uploaded file to GCS: ou4z_77ng_.parquet
# Successfully uploaded file to GCS: bwfg_ftv3_.parquet
# Successfully uploaded file to GCS: xq9b_wegg_.parquet
# Successfully uploaded file to GCS: k1es_uthj_.parquet
# Successfully uploaded file to GCS: idof_7zai_.parquet
# Successfully uploaded file to GCS: nuj8_5nxc_.parquet
# Successfully uploaded file to GCS: k1es_77k6_.parquet
# Successfully uploaded file to GCS: k1es_q7ab_.parquet
# Successfully uploaded file to GCS: ix3a_626z_.parquet
# Successfully uploaded file to GCS: nuj8_odys_.parquet
# Successfully uploaded file to GCS: bwfg_wmde_.parquet
# Successfully uploaded file to GCS: bwfg_4omy_.parquet
# Successfully uploaded file to GCS: ou4z_2wbh_.parquet
# Successfully uploaded file to GCS: bwfg_ambd_.parquet
# Successfully uploaded file to GCS: idof_mb1k_.parquet
# Successfully uploaded file to GCS: n4vi_wlkp_.parquet
# Successfully uploaded file to GCS: nuj8_75j3_.parquet
# Successfully uploaded file to GCS: bwfg_j7gt_.parquet
# Successfully uploaded file to GCS: nuj8_krt2_.parquet
# Successfully uploaded file to GCS: xq9b_srt3_.parquet
# Successfully uploaded file to GCS: bwfg_dst9_.parquet
# Successfully uploaded file to GCS: xq9b_qg3k_.parquet
# Successfully uploaded file to GCS: f02z_8g21_.parquet
# Successfully uploaded file to GCS: ou4z_j1i5_.parquet
# Successfully uploaded file to GCS: xq9b_quew_.parquet
# Successfully uploaded file to GCS: k1es_0vgw_.parquet
# Successfully uploaded file to GCS: hxj7_wnpq_.parquet
# Successfully uploaded file to GCS: f02z_q79q_.parquet
# Successfully uploaded file to GCS: k1es_c4r7_.parquet
# Successfully uploaded file to GCS: k1es_xzvf_.parquet
# Successfully uploaded file to GCS: k1es_3xqa_.parquet
# Successfully uploaded file to GCS: xq9b_kid5_.parquet
# Successfully uploaded file to GCS: hxj7_k9cx_.parquetSuccessfully uploaded file to GCS: nuj8_cut1_.parquet
# Successfully uploaded file to GCS: f02z_sz68_.parquet
# Successfully uploaded file to GCS: k1es_njrr_.parquet
# Successfully uploaded file to GCS: idof_g4lf_.parquet
# Successfully uploaded file to GCS: f02z_5k9o_.parquet
# Successfully uploaded file to GCS: nuj8_osuv_.parquet
#
# Successfully uploaded file to GCS: hxj7_trfr_.parquet
# Successfully uploaded file to GCS: idof_wr6j_.parquet
# Successfully uploaded file to GCS: f02z_7h8u_.parquet
# Successfully uploaded file to GCS: n4vi_ryze_.parquet
# Successfully uploaded file to GCS: ix3a_mk16_.parquet
# Successfully uploaded file to GCS: ix3a_o1h1_.parquet
# Successfully uploaded file to GCS: hxj7_jnqs_.parquet
# Successfully uploaded file to GCS: idof_3ojn_.parquet
# Successfully uploaded file to GCS: hxj7_i2hg_.parquet
# Successfully uploaded file to GCS: f02z_mwrb_.parquet
# Successfully uploaded file to GCS: f02z_7b40_.parquet
# Successfully uploaded file to GCS: xq9b_wy0g_.parquet
# Successfully uploaded file to GCS: hxj7_54g2_.parquet
# Successfully uploaded file to GCS: idof_0428_.parquet
# Successfully uploaded file to GCS: xq9b_wswk_.parquet
# Successfully uploaded file to GCS: ix3a_pq7i_.parquet
# Successfully uploaded file to GCS: nuj8_g7y1_.parquet
# Successfully uploaded file to GCS: f02z_60fw_.parquet
# Successfully uploaded file to GCS: xq9b_2jd3_.parquet
# Successfully uploaded file to GCS: n4vi_gi54_.parquet
# Successfully uploaded file to GCS: ix3a_fl91_.parquet
# Successfully uploaded file to GCS: f02z_yam7_.parquet
# Successfully uploaded file to GCS: xq9b_e9bk_.parquet
# Successfully uploaded file to GCS: bwfg_luyt_.parquet
# Successfully uploaded file to GCS: n4vi_a2bm_.parquet
# Successfully uploaded file to GCS: idof_yisv_.parquet
# Successfully uploaded file to GCS: hxj7_t6dp_.parquet
# Successfully uploaded file to GCS: bwfg_pxly_.parquet
# Successfully uploaded file to GCS: idof_sqm2_.parquet
# Successfully uploaded file to GCS: f02z_9zg0_.parquet
# Successfully uploaded file to GCS: ou4z_5c1b_.parquet
# Successfully uploaded file to GCS: ix3a_awb9_.parquet
# Successfully uploaded file to GCS: k1es_crn8_.parquet
# Successfully uploaded file to GCS: bwfg_9hur_.parquet
# Successfully uploaded file to GCS: f02z_a6wt_.parquet
# Successfully uploaded file to GCS: bwfg_z5rn_.parquet
# Successfully uploaded file to GCS: bwfg_b4re_.parquet
# Successfully uploaded file to GCS: ou4z_8899_.parquet
# Successfully uploaded file to GCS: n4vi_lp6q_.parquet
# Successfully uploaded file to GCS: ou4z_3uzs_.parquet
# Successfully uploaded file to GCS: nuj8_oni7_.parquet
# Successfully uploaded file to GCS: bwfg_y2e9_.parquet
# Successfully uploaded file to GCS: f02z_bfi6_.parquet
# Successfully uploaded file to GCS: f02z_11mc_.parquet
# Successfully uploaded file to GCS: hxj7_jfz4_.parquet
# Successfully uploaded file to GCS: ou4z_0mtd_.parquet
# Successfully uploaded file to GCS: ou4z_wq1i_.parquet
# Successfully uploaded file to GCS: ou4z_asn6_.parquet
# Successfully uploaded file to GCS: ix3a_w86p_.parquet
# Successfully uploaded file to GCS: n4vi_2hib_.parquet
# Successfully uploaded file to GCS: f02z_4aq8_.parquet
# Successfully uploaded file to GCS: f02z_g3uc_.parquet
# Successfully uploaded file to GCS: ou4z_sx6w_.parquet
# Successfully uploaded file to GCS: ix3a_ilel_.parquet
# Successfully uploaded file to GCS: k1es_1dq7_.parquet
# Successfully uploaded file to GCS: ou4z_p690_.parquet
# Successfully uploaded file to GCS: f02z_v217_.parquet
# Successfully uploaded file to GCS: k1es_22hd_.parquet
# Successfully uploaded file to GCS: ix3a_hbd1_.parquet
# Successfully uploaded file to GCS: bwfg_s342_.parquet
# Successfully uploaded file to GCS: f02z_n3d9_.parquet
# Successfully uploaded file to GCS: bwfg_ezc0_.parquet
# Successfully uploaded file to GCS: xq9b_ueos_.parquet
# Successfully uploaded file to GCS: ou4z_3d32_.parquet
# Successfully uploaded file to GCS: nuj8_hihn_.parquet
# Successfully uploaded file to GCS: xq9b_0ks8_.parquet
# Successfully uploaded file to GCS: hxj7_ypbw_.parquet
# Successfully uploaded file to GCS: xq9b_gbqk_.parquet
# Successfully uploaded file to GCS: ix3a_05n0_.parquet
# Successfully uploaded file to GCS: idof_64ip_.parquet
# Successfully uploaded file to GCS: k1es_7364_.parquet
# Successfully uploaded file to GCS: k1es_tg3i_.parquet
# Successfully uploaded file to GCS: n4vi_ruql_.parquet
# Successfully uploaded file to GCS: bwfg_mb08_.parquet
# Successfully uploaded file to GCS: hxj7_gnmr_.parquet
# Successfully uploaded file to GCS: idof_0nra_.parquet
# Successfully uploaded file to GCS: hxj7_hh1l_.parquet
# Successfully uploaded file to GCS: ix3a_7tit_.parquet
# Successfully uploaded file to GCS: k1es_39rc_.parquet
# Successfully uploaded file to GCS: idof_ehd6_.parquet
# Successfully uploaded file to GCS: ou4z_a3em_.parquet
# Successfully uploaded file to GCS: xq9b_xujj_.parquet
# Successfully uploaded file to GCS: n4vi_vq1o_.parquet
# Successfully uploaded file to GCS: bwfg_94xj_.parquet
# Successfully uploaded file to GCS: k1es_kffc_.parquet
# Successfully uploaded file to GCS: ix3a_xqxu_.parquet
# Successfully uploaded file to GCS: hxj7_5zwv_.parquet
# Successfully uploaded file to GCS: xq9b_j5j8_.parquet
# Successfully uploaded file to GCS: xq9b_bxio_.parquet
# Successfully uploaded file to GCS: xq9b_cj8n_.parquet
# Successfully uploaded file to GCS: bwfg_6zll_.parquet
# Successfully uploaded file to GCS: nuj8_ce27_.parquet
# Successfully uploaded file to GCS: f02z_tpva_.parquet
# Successfully uploaded file to GCS: hxj7_2skx_.parquet
# Successfully uploaded file to GCS: hxj7_73ad_.parquet
# Successfully uploaded file to GCS: xq9b_6k6j_.parquet
# Successfully uploaded file to GCS: k1es_2n7o_.parquet
# Successfully uploaded file to GCS: ix3a_hhas_.parquet
# Successfully uploaded file to GCS: idof_aqtj_.parquet
# Successfully uploaded file to GCS: ix3a_vz7x_.parquet
# Successfully uploaded file to GCS: nuj8_6s6l_.parquet
# Successfully uploaded file to GCS: idof_48zp_.parquet
# Successfully uploaded file to GCS: n4vi_w7cu_.parquet
# Successfully uploaded file to GCS: ou4z_vtvc_.parquet
# Successfully uploaded file to GCS: bwfg_eigd_.parquet
# Successfully uploaded file to GCS: ix3a_b4wm_.parquet
# Successfully uploaded file to GCS: n4vi_k35o_.parquet
# Successfully uploaded file to GCS: k1es_r6r1_.parquet
# Successfully uploaded file to GCS: idof_8j4d_.parquet
# Successfully uploaded file to GCS: k1es_np00_.parquet
# Successfully uploaded file to GCS: k1es_vic1_.parquet
# Successfully uploaded file to GCS: n4vi_4na3_.parquet
# Successfully uploaded file to GCS: ou4z_vg2z_.parquet
# Successfully uploaded file to GCS: ou4z_6vzi_.parquet
# Successfully uploaded file to GCS: bwfg_09iv_.parquet
# Successfully uploaded file to GCS: nuj8_ht6y_.parquet
# Successfully uploaded file to GCS: bwfg_8py2_.parquet
# Successfully uploaded file to GCS: n4vi_j20y_.parquet
# Successfully uploaded file to GCS: bwfg_9mbl_.parquet
# Successfully uploaded file to GCS: bwfg_akou_.parquet
# Successfully uploaded file to GCS: xq9b_3p5h_.parquet
# Successfully uploaded file to GCS: ou4z_h1kn_.parquet
# Successfully uploaded file to GCS: nuj8_dbxw_.parquet
# Successfully uploaded file to GCS: nuj8_bkgm_.parquet
# Successfully uploaded file to GCS: ou4z_lbt3_.parquet
# Successfully uploaded file to GCS: hxj7_9yys_.parquet
# Successfully uploaded file to GCS: nuj8_aaem_.parquet
# Successfully uploaded file to GCS: ou4z_9xg8_.parquet
# Successfully uploaded file to GCS: k1es_tqj0_.parquet
# Successfully uploaded file to GCS: xq9b_knwa_.parquet
# Successfully uploaded file to GCS: nuj8_ywjr_.parquet
# Successfully uploaded file to GCS: ou4z_30b7_.parquet
# Successfully uploaded file to GCS: n4vi_tuv6_.parquet
# Successfully uploaded file to GCS: f02z_fy41_.parquet
# Successfully uploaded file to GCS: nuj8_fqwb_.parquet
# Successfully uploaded file to GCS: idof_cwyp_.parquet
# Successfully uploaded file to GCS: ix3a_h3he_.parquet
# Successfully uploaded file to GCS: k1es_wvrk_.parquet
# Successfully uploaded file to GCS: bwfg_4787_.parquet
# Successfully uploaded file to GCS: hxj7_d2ug_.parquet
# Successfully uploaded file to GCS: ou4z_00th_.parquet
# Successfully uploaded file to GCS: ou4z_ahr9_.parquet
# Successfully uploaded file to GCS: hxj7_pnwo_.parquet
# Successfully uploaded file to GCS: idof_0oey_.parquet
# Successfully uploaded file to GCS: ou4z_49gl_.parquet
# Successfully uploaded file to GCS: f02z_smh9_.parquet
# Successfully uploaded file to GCS: xq9b_972o_.parquet
# Successfully uploaded file to GCS: ix3a_dizn_.parquet
# Successfully uploaded file to GCS: xq9b_kzlk_.parquet
# Successfully uploaded file to GCS: f02z_chm4_.parquet
# Successfully uploaded file to GCS: xq9b_bjn2_.parquet
# Successfully uploaded file to GCS: bwfg_3u7x_.parquet
# Successfully uploaded file to GCS: bwfg_l3z7_.parquet
# Successfully uploaded file to GCS: ix3a_4gym_.parquet
# Successfully uploaded file to GCS: f02z_r7me_.parquet
# Successfully uploaded file to GCS: idof_83o7_.parquet
# Successfully uploaded file to GCS: ou4z_hbm2_.parquet
# Successfully uploaded file to GCS: f02z_ljzo_.parquet
# Successfully uploaded file to GCS: n4vi_v0sg_.parquet
# Successfully uploaded file to GCS: ix3a_yyko_.parquet
# Successfully uploaded file to GCS: hxj7_qa6d_.parquet
# Successfully uploaded file to GCS: ou4z_pb99_.parquet
# Successfully uploaded file to GCS: bwfg_c6ed_.parquet
# Successfully uploaded file to GCS: k1es_dvia_.parquet
# Successfully uploaded file to GCS: xq9b_ubcm_.parquet
# Successfully uploaded file to GCS: xq9b_3k1v_.parquet
# Successfully uploaded file to GCS: f02z_ntyz_.parquet
# Successfully uploaded file to GCS: xq9b_c5zz_.parquet
# Successfully uploaded file to GCS: f02z_gow4_.parquet
# Successfully uploaded file to GCS: n4vi_l38h_.parquet
# Successfully uploaded file to GCS: nuj8_b191_.parquet
# Successfully uploaded file to GCS: idof_gylh_.parquet
# Successfully uploaded file to GCS: idof_6zlu_.parquet
# Successfully uploaded file to GCS: k1es_ng9x_.parquet
# Successfully uploaded file to GCS: ou4z_o8ir_.parquet
# Successfully uploaded file to GCS: nuj8_diuy_.parquet
# Successfully uploaded file to GCS: bwfg_373x_.parquet
# Successfully uploaded file to GCS: nuj8_pozo_.parquet
# Successfully uploaded file to GCS: k1es_gjd1_.parquet
# Successfully uploaded file to GCS: ou4z_o8wk_.parquet
# Successfully uploaded file to GCS: bwfg_h580_.parquet
# Successfully uploaded file to GCS: k1es_ohwg_.parquet
# Successfully uploaded file to GCS: ou4z_m5v0_.parquet
# Successfully uploaded file to GCS: f02z_8wem_.parquet
# Successfully uploaded file to GCS: n4vi_hzrn_.parquet
# Successfully uploaded file to GCS: k1es_z3up_.parquet
# Successfully uploaded file to GCS: ix3a_nudd_.parquet
# Successfully uploaded file to GCS: k1es_rb9w_.parquet
# Successfully uploaded file to GCS: hxj7_z6gz_.parquet
# Successfully uploaded file to GCS: nuj8_vs89_.parquet
# Successfully uploaded file to GCS: nuj8_3k6h_.parquet
# Successfully uploaded file to GCS: idof_qbsy_.parquet
# Successfully uploaded file to GCS: k1es_v6r3_.parquet
# Successfully uploaded file to GCS: nuj8_wq28_.parquet
# Successfully uploaded file to GCS: hxj7_4cl0_.parquet
# Successfully uploaded file to GCS: k1es_c05x_.parquet
# Successfully uploaded file to GCS: nuj8_f3el_.parquet
# Successfully uploaded file to GCS: bwfg_ybxo_.parquet
# Successfully uploaded file to GCS: nuj8_qw4c_.parquet
# Successfully uploaded file to GCS: idof_x77t_.parquet
# Successfully uploaded file to GCS: ix3a_td1j_.parquet
# Successfully uploaded file to GCS: n4vi_w9zf_.parquet
# Successfully uploaded file to GCS: hxj7_pfy6_.parquet
# Successfully uploaded file to GCS: n4vi_tyjg_.parquet
# Successfully uploaded file to GCS: bwfg_zg6a_.parquet
# Successfully uploaded file to GCS: hxj7_2zbm_.parquet
# Successfully uploaded file to GCS: hxj7_knd6_.parquet
# Successfully uploaded file to GCS: idof_c5fp_.parquet
# Successfully uploaded file to GCS: n4vi_lvzy_.parquet
# Successfully uploaded file to GCS: nuj8_rks2_.parquet
# Successfully uploaded file to GCS: ou4z_nko7_.parquet
# Successfully uploaded file to GCS: ou4z_7zbf_.parquet
# Successfully uploaded file to GCS: n4vi_nqq0_.parquet
# Successfully uploaded file to GCS: ix3a_erj9_.parquet
# Successfully uploaded file to GCS: ou4z_iuyu_.parquet
# Successfully uploaded file to GCS: k1es_ypwn_.parquet
# Successfully uploaded file to GCS: idof_6vdk_.parquet
# Successfully uploaded file to GCS: ix3a_1xca_.parquet
# Successfully uploaded file to GCS: xq9b_fypn_.parquet
# Successfully uploaded file to GCS: bwfg_efng_.parquet
# Successfully uploaded file to GCS: bwfg_7fq1_.parquet
# Successfully uploaded file to GCS: ix3a_gfk8_.parquet
# Successfully uploaded file to GCS: n4vi_h18j_.parquet
# Successfully uploaded file to GCS: k1es_2qil_.parquet
# Successfully uploaded file to GCS: hxj7_shyn_.parquet
# Successfully uploaded file to GCS: k1es_tfk1_.parquet
# Successfully uploaded file to GCS: n4vi_2bvb_.parquet
# Successfully uploaded file to GCS: xq9b_e7qw_.parquet
# Successfully uploaded file to GCS: bwfg_p6ij_.parquet
# Successfully uploaded file to GCS: k1es_axwd_.parquet
# Successfully uploaded file to GCS: ix3a_2pe6_.parquet
# Successfully uploaded file to GCS: idof_txxz_.parquet
# Successfully uploaded file to GCS: nuj8_98tb_.parquet
# Successfully uploaded file to GCS: ix3a_zkdb_.parquet
# Successfully uploaded file to GCS: ix3a_bhkv_.parquet
# Successfully uploaded file to GCS: hxj7_8wpj_.parquet
# Successfully uploaded file to GCS: bwfg_0ral_.parquet
# Successfully uploaded file to GCS: f02z_maa0_.parquet
# Successfully uploaded file to GCS: n4vi_rqd4_.parquet
# Successfully uploaded file to GCS: xq9b_vuvh_.parquet
# Successfully uploaded file to GCS: hxj7_6hzm_.parquet
# Successfully uploaded file to GCS: ou4z_pfwo_.parquet
# Successfully uploaded file to GCS: ou4z_whrc_.parquet
# Successfully uploaded file to GCS: k1es_jd1k_.parquet
# Successfully uploaded file to GCS: n4vi_j8hx_.parquet
# Successfully uploaded file to GCS: ix3a_n5ln_.parquet
# Successfully uploaded file to GCS: xq9b_qdfr_.parquet
# Successfully uploaded file to GCS: idof_eoix_.parquet
# Successfully uploaded file to GCS: f02z_8bun_.parquet
# Successfully uploaded file to GCS: nuj8_988e_.parquet
# Successfully uploaded file to GCS: ix3a_7eqf_.parquet
# Successfully uploaded file to GCS: ix3a_psqs_.parquet
# Successfully uploaded file to GCS: n4vi_sr3x_.parquet
# Successfully uploaded file to GCS: xq9b_cezg_.parquet
# Successfully uploaded file to GCS: ou4z_bgwq_.parquet
# Successfully uploaded file to GCS: bwfg_3oe3_.parquet
# Successfully uploaded file to GCS: hxj7_rt1n_.parquet
# Successfully uploaded file to GCS: ou4z_btqq_.parquet
# Successfully uploaded file to GCS: idof_yooa_.parquet
# Successfully uploaded file to GCS: n4vi_3phw_.parquet
# Successfully uploaded file to GCS: k1es_d4r2_.parquet
# Successfully uploaded file to GCS: hxj7_fjt7_.parquet
# Successfully uploaded file to GCS: nuj8_pte7_.parquet
# Successfully uploaded file to GCS: ix3a_kskh_.parquet
# Successfully uploaded file to GCS: k1es_rflm_.parquet
# Successfully uploaded file to GCS: k1es_egti_.parquet
# Successfully uploaded file to GCS: ix3a_sij3_.parquet
# Successfully uploaded file to GCS: xq9b_r4e5_.parquet
# Successfully uploaded file to GCS: k1es_psfk_.parquet
# Successfully uploaded file to GCS: hxj7_gogq_.parquet
# Successfully uploaded file to GCS: bwfg_zig0_.parquet
# Successfully uploaded file to GCS: idof_ajwn_.parquet
# Successfully uploaded file to GCS: ix3a_qwip_.parquet
# Successfully uploaded file to GCS: ix3a_lx4s_.parquet
# Successfully uploaded file to GCS: n4vi_6bw4_.parquet
# Successfully uploaded file to GCS: bwfg_eycx_.parquet
# Successfully uploaded file to GCS: idof_0zbe_.parquet
# Successfully uploaded file to GCS: bwfg_6oqz_.parquet
# Successfully uploaded file to GCS: bwfg_t40p_.parquet
# Successfully uploaded file to GCS: f02z_9od5_.parquet
# Successfully uploaded file to GCS: k1es_r070_.parquet
# Successfully uploaded file to GCS: hxj7_g9fs_.parquet
# Successfully uploaded file to GCS: bwfg_w6vb_.parquet
# Successfully uploaded file to GCS: nuj8_68nl_.parquet
# Successfully uploaded file to GCS: f02z_iu3l_.parquet
# Successfully uploaded file to GCS: nuj8_um90_.parquet
# Successfully uploaded file to GCS: ix3a_pj0i_.parquet
# Successfully uploaded file to GCS: nuj8_23az_.parquet
# Successfully uploaded file to GCS: f02z_cvxs_.parquet
# Successfully uploaded file to GCS: f02z_hs41_.parquet
# Successfully uploaded file to GCS: ix3a_y9w7_.parquet
# Successfully uploaded file to GCS: nuj8_xdcf_.parquet
# Successfully uploaded file to GCS: hxj7_hxar_.parquet
# Successfully uploaded file to GCS: xq9b_okoe_.parquet
# Successfully uploaded file to GCS: xq9b_z4se_.parquet
# Successfully uploaded file to GCS: n4vi_dcr1_.parquet
# Successfully uploaded file to GCS: xq9b_pbxm_.parquet
# Successfully uploaded file to GCS: n4vi_gq0i_.parquet
# Successfully uploaded file to GCS: n4vi_04fw_.parquet
# Successfully uploaded file to GCS: bwfg_4kl1_.parquet
# Successfully uploaded file to GCS: bwfg_xdwr_.parquet
# Successfully uploaded file to GCS: nuj8_vxhl_.parquet
# Successfully uploaded file to GCS: nuj8_110u_.parquet
# Successfully uploaded file to GCS: hxj7_kkfo_.parquet
# Successfully uploaded file to GCS: n4vi_xj78_.parquet
# Successfully uploaded file to GCS: k1es_1l5v_.parquet
# Successfully uploaded file to GCS: nuj8_n6cp_.parquet
# Successfully uploaded file to GCS: k1es_9xhp_.parquet
# Successfully uploaded file to GCS: ou4z_b9d0_.parquet
# Successfully uploaded file to GCS: n4vi_hpkm_.parquet
# Successfully uploaded file to GCS: k1es_r601_.parquet
# Successfully uploaded file to GCS: n4vi_xu6d_.parquet
# Successfully uploaded file to GCS: f02z_nlft_.parquet
# Successfully uploaded file to GCS: nuj8_nt5h_.parquet
# Successfully uploaded file to GCS: xq9b_cgvx_.parquet
# Successfully uploaded file to GCS: bwfg_ss7h_.parquet
# Successfully uploaded file to GCS: bwfg_du3c_.parquet
# Successfully uploaded file to GCS: ix3a_71oj_.parquet
# Successfully uploaded file to GCS: idof_ry3s_.parquet
# Successfully uploaded file to GCS: k1es_j584_.parquet
# Successfully uploaded file to GCS: xq9b_4nu2_.parquet
# Successfully uploaded file to GCS: k1es_6w02_.parquet
# Successfully uploaded file to GCS: bwfg_2a73_.parquet
# Successfully uploaded file to GCS: hxj7_rcd5_.parquet
# Successfully uploaded file to GCS: ix3a_0sdv_.parquet
# Successfully uploaded file to GCS: n4vi_zdwv_.parquet
# Successfully uploaded file to GCS: k1es_lz27_.parquet
# Successfully uploaded file to GCS: hxj7_w2xp_.parquet
# Successfully uploaded file to GCS: n4vi_pts7_.parquet
# Successfully uploaded file to GCS: nuj8_xoig_.parquet
# Successfully uploaded file to GCS: hxj7_r7et_.parquet
# Successfully uploaded file to GCS: ix3a_smdv_.parquet
# Successfully uploaded file to GCS: k1es_qfu1_.parquet
# Successfully uploaded file to GCS: f02z_7497_.parquet
# Successfully uploaded file to GCS: xq9b_2p7g_.parquet
# Successfully uploaded file to GCS: nuj8_gh51_.parquet
# Successfully uploaded file to GCS: nuj8_wk3x_.parquet
# Successfully uploaded file to GCS: hxj7_l48n_.parquet
# Successfully uploaded file to GCS: n4vi_w76z_.parquet
# Successfully uploaded file to GCS: hxj7_mf3j_.parquet
# Successfully uploaded file to GCS: f02z_wm9e_.parquet
# Successfully uploaded file to GCS: ou4z_dimg_.parquet
# Successfully uploaded file to GCS: bwfg_6tvb_.parquet
# Successfully uploaded file to GCS: bwfg_yh6k_.parquet
# Successfully uploaded file to GCS: idof_2hdx_.parquet
# Successfully uploaded file to GCS: hxj7_9ryd_.parquet
# Successfully uploaded file to GCS: n4vi_t1it_.parquet
# Successfully uploaded file to GCS: nuj8_yds0_.parquet
# Successfully uploaded file to GCS: idof_essh_.parquet
# Successfully uploaded file to GCS: nuj8_e7y1_.parquet
# Successfully uploaded file to GCS: ix3a_8wat_.parquet
# Successfully uploaded file to GCS: ou4z_5ovb_.parquet
# Successfully uploaded file to GCS: ix3a_0c1e_.parquet
# Successfully uploaded file to GCS: f02z_p0s7_.parquet
# Successfully uploaded file to GCS: nuj8_aa7w_.parquet
# Successfully uploaded file to GCS: bwfg_i0y6_.parquet
# Successfully uploaded file to GCS: k1es_o7vy_.parquet
# Successfully uploaded file to GCS: idof_9jcm_.parquet
# Successfully uploaded file to GCS: hxj7_liwy_.parquet
# Successfully uploaded file to GCS: idof_q0xo_.parquet
# Successfully uploaded file to GCS: idof_9qwk_.parquet
# Successfully uploaded file to GCS: ix3a_0pme_.parquet
# Successfully uploaded file to GCS: nuj8_cvyo_.parquet
# Successfully uploaded file to GCS: idof_ox4q_.parquet
# Successfully uploaded file to GCS: ou4z_vdye_.parquet
# Successfully uploaded file to GCS: idof_97v8_.parquet
# Successfully uploaded file to GCS: nuj8_anqg_.parquet
# Successfully uploaded file to GCS: k1es_kyir_.parquet
# Successfully uploaded file to GCS: n4vi_4fn1_.parquet
# Successfully uploaded file to GCS: idof_0ryh_.parquet
# Successfully uploaded file to GCS: hxj7_qwf1_.parquet
# Successfully uploaded file to GCS: ix3a_xkhr_.parquet
# Successfully uploaded file to GCS: k1es_s54n_.parquet
# Successfully uploaded file to GCS: k1es_2k6c_.parquet
# Successfully uploaded file to GCS: xq9b_r0lw_.parquet
# Successfully uploaded file to GCS: ou4z_dd06_.parquet
# Successfully uploaded file to GCS: ix3a_nz6d_.parquet
# Successfully uploaded file to GCS: bwfg_qsu1_.parquet
# Successfully uploaded file to GCS: bwfg_x2v2_.parquet
# Successfully uploaded file to GCS: xq9b_ylv6_.parquet
# Successfully uploaded file to GCS: idof_zjl8_.parquet
# Successfully uploaded file to GCS: k1es_b0oe_.parquet
# Successfully uploaded file to GCS: nuj8_sd0w_.parquet
# Successfully uploaded file to GCS: n4vi_thgl_.parquet
# Successfully uploaded file to GCS: k1es_0ro7_.parquet
# Successfully uploaded file to GCS: xq9b_z0p0_.parquet
# Successfully uploaded file to GCS: k1es_muzc_.parquet
# Successfully uploaded file to GCS: xq9b_sr1i_.parquet
# Successfully uploaded file to GCS: ou4z_q2pc_.parquet
# Successfully uploaded file to GCS: bwfg_7azg_.parquet
# Successfully uploaded file to GCS: hxj7_yu8e_.parquet
# Successfully uploaded file to GCS: f02z_bzw6_.parquet
# Successfully uploaded file to GCS: bwfg_gnyn_.parquet
# Successfully uploaded file to GCS: n4vi_jteg_.parquet
# Successfully uploaded file to GCS: ou4z_93r5_.parquet
# Successfully uploaded file to GCS: n4vi_xaad_.parquet
# Successfully uploaded file to GCS: bwfg_rne4_.parquet
# Successfully uploaded file to GCS: k1es_hgsi_.parquet
# Successfully uploaded file to GCS: n4vi_al6m_.parquet
# Successfully uploaded file to GCS: nuj8_05qd_.parquet
# Successfully uploaded file to GCS: ou4z_dzgr_.parquet
# Successfully uploaded file to GCS: ix3a_60yu_.parquet
# Successfully uploaded file to GCS: bwfg_nz2q_.parquet
# Successfully uploaded file to GCS: xq9b_fab6_.parquet
# Successfully uploaded file to GCS: xq9b_vq25_.parquet
# Successfully uploaded file to GCS: idof_xf0d_.parquet
# Successfully uploaded file to GCS: bwfg_0die_.parquet
# Successfully uploaded file to GCS: n4vi_07fg_.parquet
# Successfully uploaded file to GCS: idof_of2d_.parquet
# Successfully uploaded file to GCS: nuj8_ogpo_.parquet
# Successfully uploaded file to GCS: ix3a_vxos_.parquet
# Successfully uploaded file to GCS: nuj8_upz1_.parquet
# Successfully uploaded file to GCS: n4vi_cq00_.parquet
# Successfully uploaded file to GCS: ix3a_vg7u_.parquet
# Successfully uploaded file to GCS: hxj7_5x6v_.parquet
# Successfully uploaded file to GCS: idof_mcor_.parquet
# Successfully uploaded file to GCS: n4vi_jd3s_.parquet
# Successfully uploaded file to GCS: n4vi_1wfv_.parquet
# Successfully uploaded file to GCS: xq9b_ovx2_.parquet
# Successfully uploaded file to GCS: bwfg_5ayo_.parquet
# Successfully uploaded file to GCS: n4vi_v7pd_.parquet
# Successfully uploaded file to GCS: f02z_b8b4_.parquet
# Successfully uploaded file to GCS: ou4z_rkjd_.parquet
# Successfully uploaded file to GCS: bwfg_zr6q_.parquet
# Successfully uploaded file to GCS: xq9b_lz05_.parquet
# Successfully uploaded file to GCS: ou4z_mtyy_.parquet
# Successfully uploaded file to GCS: bwfg_pv37_.parquet
# Successfully uploaded file to GCS: f02z_68dh_.parquet
# Successfully uploaded file to GCS: xq9b_w2pi_.parquet
# Successfully uploaded file to GCS: ix3a_j8oc_.parquet
# Successfully uploaded file to GCS: f02z_d4n9_.parquet
# Successfully uploaded file to GCS: hxj7_oelr_.parquet
# Successfully uploaded file to GCS: bwfg_3hrw_.parquet
# Successfully uploaded file to GCS: bwfg_a8t3_.parquet
# Successfully uploaded file to GCS: n4vi_yhwu_.parquet
# Successfully uploaded file to GCS: idof_fbj5_.parquet
# Successfully uploaded file to GCS: ix3a_m16v_.parquet
# Successfully uploaded file to GCS: hxj7_d3l8_.parquet
# Successfully uploaded file to GCS: nuj8_c3os_.parquet
# Successfully uploaded file to GCS: bwfg_qm5j_.parquet
# Successfully uploaded file to GCS: xq9b_b0cn_.parquet
# Successfully uploaded file to GCS: ix3a_ydzb_.parquet
# Successfully uploaded file to GCS: ix3a_xd7v_.parquet
# Successfully uploaded file to GCS: f02z_382x_.parquet
# Successfully uploaded file to GCS: bwfg_w1z0_.parquet
# Successfully uploaded file to GCS: ou4z_cj2y_.parquet
# Successfully uploaded file to GCS: k1es_yhhh_.parquet
# Successfully uploaded file to GCS: nuj8_og6f_.parquet
# Successfully uploaded file to GCS: ix3a_jfko_.parquet
# Successfully uploaded file to GCS: ix3a_jkxm_.parquet
# Successfully uploaded file to GCS: k1es_1ast_.parquet
# Successfully uploaded file to GCS: bwfg_z72l_.parquet
# Successfully uploaded file to GCS: nuj8_brge_.parquet
# Successfully uploaded file to GCS: bwfg_6ya7_.parquet
# Successfully uploaded file to GCS: ix3a_53t9_.parquet
# Successfully uploaded file to GCS: hxj7_mqwj_.parquet
# Successfully uploaded file to GCS: ix3a_b1gk_.parquet
# Successfully uploaded file to GCS: bwfg_y9yq_.parquet
# Successfully uploaded file to GCS: ix3a_zfsl_.parquet
# Successfully uploaded file to GCS: ix3a_vo90_.parquet
# Successfully uploaded file to GCS: bwfg_zwwk_.parquet
# Successfully uploaded file to GCS: k1es_panc_.parquet
# Successfully uploaded file to GCS: idof_wrqm_.parquet
# Successfully uploaded file to GCS: ix3a_tiym_.parquet
# Successfully uploaded file to GCS: idof_tfwy_.parquet
# Successfully uploaded file to GCS: n4vi_tgvw_.parquet
# Successfully uploaded file to GCS: ou4z_qltx_.parquet
# Successfully uploaded file to GCS: xq9b_zek1_.parquet
# Successfully uploaded file to GCS: ou4z_eiq0_.parquet
# Successfully uploaded file to GCS: f02z_uq83_.parquet
# Successfully uploaded file to GCS: k1es_zd0e_.parquet
# Successfully uploaded file to GCS: n4vi_mx9g_.parquet
# Successfully uploaded file to GCS: k1es_tvkt_.parquet
# Successfully uploaded file to GCS: f02z_80m8_.parquet
# Successfully uploaded file to GCS: nuj8_kese_.parquet
# Successfully uploaded file to GCS: hxj7_w478_.parquet
# Successfully uploaded file to GCS: ou4z_b5x6_.parquet
# Successfully uploaded file to GCS: nuj8_srfr_.parquet
# ...
# Successfully uploaded file to GCS: ix3a_db4g_.parquet
# Successfully uploaded file to GCS: f02z_bc2l_.parquet
# Successfully uploaded file to GCS: ix3a_1g9l_.parquet
# Successfully uploaded file to GCS: xq9b_bxzh_.parquet
# Successfully uploaded file to GCS: ix3a_7np7_.parquet
# Successfully uploaded file to GCS: k1es_c6rz_.parquet
# Successfully uploaded file to GCS: xq9b_k0tm_.parquet
# Successfully uploaded file to GCS: n4vi_x60z_.parquet
# Successfully uploaded file to GCS: n4vi_a766_.parquet
# Successfully uploaded file to GCS: idof_fv2o_.parquet
# Successfully uploaded file to GCS: k1es_7o0v_.parquet
# Successfully uploaded file to GCS: ix3a_0fwe_.parquet
# Successfully uploaded file to GCS: xq9b_wd1z_.parquet
# Successfully uploaded file to GCS: bwfg_56bb_.parquet
# Successfully uploaded file to GCS: bwfg_au2f_.parquet
# Successfully uploaded file to GCS: n4vi_5bvm_.parquet
# Successfully uploaded file to GCS: f02z_swmv_.parquet
# Successfully uploaded file to GCS: k1es_rm8v_.parquet
# Successfully uploaded file to GCS: idof_9vsa_.parquet
# Successfully uploaded file to GCS: bwfg_o29b_.parquet
# Successfully uploaded file to GCS: hxj7_t9b4_.parquet
# Successfully uploaded file to GCS: xq9b_w77a_.parquet
# Successfully uploaded file to GCS: k1es_4s25_.parquet
# Successfully uploaded file to GCS: n4vi_i8m8_.parquet
# Successfully uploaded file to GCS: ix3a_xm6h_.parquet
# Successfully uploaded file to GCS: nuj8_8bv0_.parquet
# Successfully uploaded file to GCS: hxj7_1t3k_.parquet
# Successfully uploaded file to GCS: f02z_ogdp_.parquet
# Successfully uploaded file to GCS: hxj7_ovc4_.parquet
# Successfully uploaded file to GCS: f02z_uk1r_.parquet
# Successfully uploaded file to GCS: hxj7_fshr_.parquet
# Successfully uploaded file to GCS: ou4z_o32z_.parquet
# Successfully uploaded file to GCS: k1es_3ula_.parquet
# Successfully uploaded file to GCS: ou4z_xy80_.parquet
# Successfully uploaded file to GCS: hxj7_jsja_.parquet
# Successfully uploaded file to GCS: nuj8_yb4z_.parquet
# Successfully uploaded file to GCS: f02z_p6cg_.parquet
# Successfully uploaded file to GCS: nuj8_vvg8_.parquet
# Successfully uploaded file to GCS: k1es_y39m_.parquet
# Successfully uploaded file to GCS: xq9b_xka0_.parquet
# Successfully uploaded file to GCS: f02z_l0h4_.parquet
# Successfully uploaded file to GCS: f02z_pi5v_.parquet
# Successfully uploaded file to GCS: hxj7_n5m0_.parquet
# Successfully uploaded file to GCS: nuj8_2ra2_.parquet
# Successfully uploaded file to GCS: idof_hbb4_.parquet
# Successfully uploaded file to GCS: xq9b_hia6_.parquet
# Successfully uploaded file to GCS: bwfg_b8a2_.parquet
# Successfully uploaded file to GCS: f02z_13rd_.parquet
# Successfully uploaded file to GCS: n4vi_u4gx_.parquet
# Successfully uploaded file to GCS: ix3a_sok0_.parquet
# Successfully uploaded file to GCS: f02z_tc86_.parquet
# Successfully uploaded file to GCS: n4vi_4uho_.parquet
# Successfully uploaded file to GCS: hxj7_1i0y_.parquet
# Successfully uploaded file to GCS: ix3a_fj2g_.parquet
# Successfully uploaded file to GCS: nuj8_o3ys_.parquet
# Successfully uploaded file to GCS: f02z_dktz_.parquet
# Successfully uploaded file to GCS: bwfg_nql7_.parquet
# Successfully uploaded file to GCS: f02z_z75d_.parquet
# Successfully uploaded file to GCS: hxj7_cdym_.parquet
# Successfully uploaded file to GCS: nuj8_zw2j_.parquet
# Successfully uploaded file to GCS: ix3a_r72b_.parquet
# Successfully uploaded file to GCS: ou4z_czme_.parquet
# Successfully uploaded file to GCS: bwfg_odtu_.parquet
# Successfully uploaded file to GCS: k1es_rlwn_.parquet
# Successfully uploaded file to GCS: k1es_1pe0_.parquet
# Successfully uploaded file to GCS: idof_3lf5_.parquet
# Successfully uploaded file to GCS: n4vi_oa34_.parquet
# Successfully uploaded file to GCS: hxj7_cu66_.parquet
# Successfully uploaded file to GCS: xq9b_yjo0_.parquet
# Successfully uploaded file to GCS: hxj7_1fxz_.parquet
# Successfully uploaded file to GCS: k1es_c8xy_.parquet
# Successfully uploaded file to GCS: idof_3xrg_.parquet
# Successfully uploaded file to GCS: hxj7_bbqn_.parquet
# Successfully uploaded file to GCS: k1es_ds2m_.parquet
# Successfully uploaded file to GCS: k1es_1dot_.parquet
# Successfully uploaded file to GCS: n4vi_ecw4_.parquet
# Successfully uploaded file to GCS: ou4z_hqt7_.parquet
# Successfully uploaded file to GCS: bwfg_igm5_.parquet
# Successfully uploaded file to GCS: hxj7_viq3_.parquet
# Successfully uploaded file to GCS: ix3a_e9l0_.parquet
# Successfully uploaded file to GCS: n4vi_asua_.parquet
# Successfully uploaded file to GCS: k1es_kxs8_.parquet
# Successfully uploaded file to GCS: xq9b_izmt_.parquet
# Successfully uploaded file to GCS: f02z_1b51_.parquet
# Successfully uploaded file to GCS: ou4z_1sez_.parquet
# Successfully uploaded file to GCS: nuj8_kfkc_.parquet
# Successfully uploaded file to GCS: k1es_ad26_.parquet
# Successfully uploaded file to GCS: bwfg_2fce_.parquet
# Successfully uploaded file to GCS: idof_zybm_.parquet
# Successfully uploaded file to GCS: idof_7bfc_.parquet
# Successfully uploaded file to GCS: ix3a_lih6_.parquet
# Successfully uploaded file to GCS: xq9b_kb6f_.parquet
# Successfully uploaded file to GCS: bwfg_3lif_.parquet
# Successfully uploaded file to GCS: k1es_7zqq_.parquet
# Successfully uploaded file to GCS: f02z_k1gc_.parquet
# Successfully uploaded file to GCS: k1es_vu99_.parquet
# Successfully uploaded file to GCS: ou4z_v69g_.parquet
# Successfully uploaded file to GCS: ix3a_sjf4_.parquet
# Successfully uploaded file to GCS: nuj8_vpmx_.parquet
# Successfully uploaded file to GCS: idof_o1iq_.parquet
# Successfully uploaded file to GCS: nuj8_66p9_.parquet
# Successfully uploaded file to GCS: xq9b_aj6p_.parquet
# Successfully uploaded file to GCS: xq9b_ggvy_.parquet
# Successfully uploaded file to GCS: ix3a_n5pi_.parquet
# Successfully uploaded file to GCS: ix3a_b4vv_.parquet
# Successfully uploaded file to GCS: nuj8_we78_.parquet
# Successfully uploaded file to GCS: xq9b_4h7o_.parquet
# Successfully uploaded file to GCS: ix3a_vp8p_.parquet
# Successfully uploaded file to GCS: hxj7_fsse_.parquet
# Successfully uploaded file to GCS: nuj8_ovmw_.parquet
# Successfully uploaded file to GCS: k1es_xlsg_.parquet
# Successfully uploaded file to GCS: hxj7_d9se_.parquet
# Successfully uploaded file to GCS: ou4z_nlzy_.parquet
# Successfully uploaded file to GCS: hxj7_b3pl_.parquet
# Successfully uploaded file to GCS: k1es_4xyb_.parquet
# Successfully uploaded file to GCS: k1es_gip8_.parquet
# Successfully uploaded file to GCS: nuj8_9qb3_.parquet
# Successfully uploaded file to GCS: f02z_84la_.parquet
# Successfully uploaded file to GCS: ou4z_hekv_.parquet
# Successfully uploaded file to GCS: ix3a_kj94_.parquet
# Successfully uploaded file to GCS: hxj7_kqhl_.parquet
# Successfully uploaded file to GCS: ix3a_zaml_.parquet
# Successfully uploaded file to GCS: bwfg_k53o_.parquet
# Successfully uploaded file to GCS: ou4z_9c4a_.parquet
# Successfully uploaded file to GCS: ou4z_ckai_.parquet
# Successfully uploaded file to GCS: k1es_1teo_.parquet
# Successfully uploaded file to GCS: ix3a_v3ih_.parquet
# Successfully uploaded file to GCS: bwfg_mcb4_.parquet
# Successfully uploaded file to GCS: idof_scyb_.parquet
# Successfully uploaded file to GCS: f02z_uqza_.parquet
# Successfully uploaded file to GCS: idof_ect1_.parquet
# Successfully uploaded file to GCS: f02z_1gao_.parquet
# Successfully uploaded file to GCS: hxj7_13eo_.parquet
# Successfully uploaded file to GCS: ix3a_wj7e_.parquet
# Successfully uploaded file to GCS: hxj7_0p0c_.parquet
# Successfully uploaded file to GCS: bwfg_hu91_.parquet
# Successfully uploaded file to GCS: ix3a_t7t2_.parquet
# Successfully uploaded file to GCS: xq9b_1kyv_.parquet
# Successfully uploaded file to GCS: n4vi_uqgm_.parquet
# Successfully uploaded file to GCS: idof_0us7_.parquet
# Successfully uploaded file to GCS: f02z_jvxx_.parquet
# Successfully uploaded file to GCS: n4vi_a4nn_.parquet
# Successfully uploaded file to GCS: k1es_a9wa_.parquet
# Successfully uploaded file to GCS: f02z_teu5_.parquet
# Successfully uploaded file to GCS: nuj8_2t9k_.parquet
# Successfully uploaded file to GCS: hxj7_9mpw_.parquet
# Successfully uploaded file to GCS: k1es_j45k_.parquet
# Successfully uploaded file to GCS: n4vi_3tq5_.parquet
# Successfully uploaded file to GCS: bwfg_8q4x_.parquet
# Successfully uploaded file to GCS: idof_8gs3_.parquet
# Successfully uploaded file to GCS: idof_ut08_.parquet
# Successfully uploaded file to GCS: f02z_hr7s_.parquet
# Successfully uploaded file to GCS: idof_8x6n_.parquet
# Successfully uploaded file to GCS: ix3a_epr1_.parquet
# Successfully uploaded file to GCS: xq9b_67cv_.parquet
# Successfully uploaded file to GCS: f02z_w8t0_.parquet
# Successfully uploaded file to GCS: xq9b_o434_.parquet
# Successfully uploaded file to GCS: ou4z_6w2d_.parquet
# Successfully uploaded file to GCS: f02z_smcf_.parquet
# Successfully uploaded file to GCS: xq9b_frt0_.parquet
# Successfully uploaded file to GCS: k1es_onj0_.parquet
# Successfully uploaded file to GCS: ix3a_ooo2_.parquet
# Successfully uploaded file to GCS: ix3a_8hx8_.parquet
# Successfully uploaded file to GCS: f02z_ey2r_.parquet
# Successfully uploaded file to GCS: xq9b_9q5x_.parquet
# Successfully uploaded file to GCS: nuj8_8icb_.parquet
# Successfully uploaded file to GCS: n4vi_wtgt_.parquet
# Successfully uploaded file to GCS: bwfg_wofr_.parquet
# Successfully uploaded file to GCS: hxj7_98te_.parquet
# Successfully uploaded file to GCS: nuj8_2ln9_.parquet
# Successfully uploaded file to GCS: bwfg_xk77_.parquet
# Successfully uploaded file to GCS: ix3a_7g1w_.parquet
# Successfully uploaded file to GCS: xq9b_2otf_.parquet
# Successfully uploaded file to GCS: ou4z_op2w_.parquet
# Successfully uploaded file to GCS: hxj7_tsbd_.parquet
# Successfully uploaded file to GCS: n4vi_wbnj_.parquet
# Successfully uploaded file to GCS: ou4z_zc0g_.parquet
# Successfully uploaded file to GCS: nuj8_o5n1_.parquet
# Successfully uploaded file to GCS: bwfg_lel8_.parquet
# Successfully uploaded file to GCS: hxj7_oh5j_.parquet
# Successfully uploaded file to GCS: idof_fg7j_.parquet
# Successfully uploaded file to GCS: nuj8_uhyf_.parquet
# Successfully uploaded file to GCS: xq9b_coxq_.parquet
# Successfully uploaded file to GCS: hxj7_d999_.parquet
# Successfully uploaded file to GCS: idof_fd8p_.parquet
# Successfully uploaded file to GCS: ou4z_ro59_.parquet
# Successfully uploaded file to GCS: f02z_8hcv_.parquet
# Successfully uploaded file to GCS: n4vi_52ma_.parquet
# Successfully uploaded file to GCS: k1es_it86_.parquet
# Successfully uploaded file to GCS: bwfg_01pb_.parquet
# Successfully uploaded file to GCS: hxj7_rj94_.parquet
# Successfully uploaded file to GCS: f02z_v0c1_.parquet
# Successfully uploaded file to GCS: k1es_6tyn_.parquet
# Successfully uploaded file to GCS: ou4z_6era_.parquet
# Successfully uploaded file to GCS: f02z_opqc_.parquet
# Successfully uploaded file to GCS: ou4z_qb8n_.parquet
# Successfully uploaded file to GCS: k1es_vx65_.parquet
# Successfully uploaded file to GCS: n4vi_0m1x_.parquet
# Successfully uploaded file to GCS: hxj7_uka4_.parquet
# Successfully uploaded file to GCS: idof_r8vk_.parquet
# Successfully uploaded file to GCS: f02z_7wiw_.parquet
# Successfully uploaded file to GCS: nuj8_1vmi_.parquet
# Successfully uploaded file to GCS: ou4z_3i1t_.parquet
# Successfully uploaded file to GCS: nuj8_l2cz_.parquet
# Successfully uploaded file to GCS: k1es_2dm8_.parquet
# Successfully uploaded file to GCS: k1es_zgvg_.parquet
# Successfully uploaded file to GCS: idof_782v_.parquet
# Successfully uploaded file to GCS: bwfg_ohlc_.parquet
# Successfully uploaded file to GCS: bwfg_thx0_.parquet
# Successfully uploaded file to GCS: hxj7_t6u2_.parquet
# Successfully uploaded file to GCS: n4vi_tn10_.parquet
# Successfully uploaded file to GCS: k1es_elgd_.parquet
# Successfully uploaded file to GCS: xq9b_ywk1_.parquet
# Successfully uploaded file to GCS: ix3a_o5oc_.parquet
# Successfully uploaded file to GCS: xq9b_gf4v_.parquet
# Successfully uploaded file to GCS: k1es_1q75_.parquet
# Successfully uploaded file to GCS: f02z_50mw_.parquet
# Successfully uploaded file to GCS: hxj7_5h7l_.parquet
# Successfully uploaded file to GCS: xq9b_qv66_.parquet
# Successfully uploaded file to GCS: ou4z_tpd8_.parquet
# Successfully uploaded file to GCS: ou4z_yq7l_.parquet
# Successfully uploaded file to GCS: xq9b_6lso_.parquet
# Successfully uploaded file to GCS: k1es_8c9t_.parquet
# Successfully uploaded file to GCS: nuj8_jlea_.parquet
# Successfully uploaded file to GCS: xq9b_7f11_.parquet
# Successfully uploaded file to GCS: bwfg_2g6n_.parquet
# Successfully uploaded file to GCS: n4vi_g1f4_.parquet
# Successfully uploaded file to GCS: f02z_9332_.parquet
# Successfully uploaded file to GCS: n4vi_k3bd_.parquet
# Successfully uploaded file to GCS: idof_naew_.parquet
# Successfully uploaded file to GCS: k1es_rh3i_.parquet
# Successfully uploaded file to GCS: k1es_06rj_.parquet
# Successfully uploaded file to GCS: xq9b_4b2c_.parquet
# Successfully uploaded file to GCS: ou4z_4m16_.parquet
# Successfully uploaded file to GCS: n4vi_x7i7_.parquet
# Successfully uploaded file to GCS: n4vi_r280_.parquet
# Successfully uploaded file to GCS: idof_3rrt_.parquet
# Successfully uploaded file to GCS: idof_trkb_.parquet
# Successfully uploaded file to GCS: hxj7_2oel_.parquet
# Successfully uploaded file to GCS: hxj7_6qri_.parquet
# Successfully uploaded file to GCS: idof_j2rr_.parquet
# Successfully uploaded file to GCS: bwfg_j2vl_.parquet
# Successfully uploaded file to GCS: f02z_huhp_.parquet
# Successfully uploaded file to GCS: n4vi_cx2n_.parquet
# Successfully uploaded file to GCS: xq9b_tdd3_.parquet
# Successfully uploaded file to GCS: ix3a_w5j7_.parquet
# Successfully uploaded file to GCS: n4vi_0xwt_.parquet
# Successfully uploaded file to GCS: ix3a_3ne8_.parquet
# Successfully uploaded file to GCS: nuj8_etnx_.parquet
# Successfully uploaded file to GCS: hxj7_5ug3_.parquet
# Successfully uploaded file to GCS: hxj7_oiyg_.parquet
# Successfully uploaded file to GCS: xq9b_kcpg_.parquet
# Successfully uploaded file to GCS: n4vi_t6gb_.parquet
# Successfully uploaded file to GCS: n4vi_4kgc_.parquet
# Successfully uploaded file to GCS: nuj8_9ur4_.parquet
# Successfully uploaded file to GCS: k1es_k5nj_.parquet
# Successfully uploaded file to GCS: n4vi_nxst_.parquet
# Successfully uploaded file to GCS: f02z_nwxc_.parquet
# Successfully uploaded file to GCS: idof_2az7_.parquet
# Successfully uploaded file to GCS: hxj7_1yit_.parquet
# Successfully uploaded file to GCS: k1es_cgkj_.parquet
# Successfully uploaded file to GCS: hxj7_6iue_.parquet
# Successfully uploaded file to GCS: f02z_lfi6_.parquet
# Successfully uploaded file to GCS: xq9b_7qob_.parquet
# Successfully uploaded file to GCS: k1es_jc4l_.parquet
# Successfully uploaded file to GCS: hxj7_e500_.parquet
# Successfully uploaded file to GCS: n4vi_ymjc_.parquet
# Successfully uploaded file to GCS: nuj8_nqg0_.parquet
# Successfully uploaded file to GCS: xq9b_87t1_.parquet
# Successfully uploaded file to GCS: ix3a_142o_.parquet
# Successfully uploaded file to GCS: n4vi_22zg_.parquet
# Successfully uploaded file to GCS: xq9b_bbg8_.parquet
# Successfully uploaded file to GCS: idof_eij5_.parquet
# Successfully uploaded file to GCS: ou4z_pqra_.parquet
# Successfully uploaded file to GCS: ou4z_q545_.parquet
# Successfully uploaded file to GCS: bwfg_0jvw_.parquet
# Successfully uploaded file to GCS: nuj8_oyz4_.parquet
# Successfully uploaded file to GCS: xq9b_qzk7_.parquet
# Successfully uploaded file to GCS: k1es_t7mn_.parquet
# Successfully uploaded file to GCS: f02z_ftsr_.parquet
# Successfully uploaded file to GCS: n4vi_b278_.parquet
# Successfully uploaded file to GCS: idof_kg4p_.parquet
# Successfully uploaded file to GCS: xq9b_6bz6_.parquet
# Successfully uploaded file to GCS: hxj7_hler_.parquet
# Successfully uploaded file to GCS: f02z_ybg8_.parquet
# Successfully uploaded file to GCS: xq9b_twbl_.parquet
# Successfully uploaded file to GCS: bwfg_9wj9_.parquet
# Successfully uploaded file to GCS: nuj8_gsk9_.parquet
# Successfully uploaded file to GCS: ix3a_srhn_.parquet
# Successfully uploaded file to GCS: bwfg_kcmg_.parquet
# Successfully uploaded file to GCS: hxj7_mjxc_.parquet
# Successfully uploaded file to GCS: hxj7_iio8_.parquet
# Successfully uploaded file to GCS: ou4z_pgkq_.parquet
# Successfully uploaded file to GCS: idof_inrh_.parquet
# Successfully uploaded file to GCS: nuj8_ifjc_.parquet
# End time: 2024-10-19 22:49:05.633123
# Elapsed time: 0:19:55.774901

# %%
type(fake.year())
# Out:
# str

# %%
fake.day_of_month()

# %%
fake.name() + ", " + fake.phone_number()
# Out:
# 'Mackenzie Taylor, 001-598-214-2199'

# %%
equipamento_status =  ["quebrado", "alerta",'ativo', 'inativo', 'manutenção']
status = random.choice(equipamento_status)
events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]

ex_data = {
    "eventType": 'NULL' if status in ["quebrado", "inativo"] else random.choice(events),
    "status": status
}

print(ex_data)
# Out:
# {'eventType': 'depressurize', 'status': 'alerta'}

# %%
# Define the possible statuses with weighted occurrences
equipamento_status = ["ativo"] * 8 + ["quebrado", "alerta", "inativo", "manutenção"] * 2
status = random.choice(equipamento_status)
events = ["unfreeze", "depressurize", "warm", "", "pressurize", "normalize"]

# Use a conditional expression to set the eventType
ex_data = {
    "eventType": 'NULL' if status in ["quebrado", "inativo"] else random.choice(events),
    "status": status
}

print(ex_data)
# Out:
# {'eventType': 'warm', 'status': 'ativo'}

# %%
equipamento_status
# Out:
# ['ativo',
#  'ativo',
#  'ativo',
#  'ativo',
#  'ativo',
#  'ativo',
#  'ativo',
#  'ativo',
#  'quebrado',
#  'alerta',
#  'inativo',
#  'manutenção',
#  'quebrado',
#  'alerta',
#  'inativo',
#  'manutenção']

# %%
df = pd.read_parquet("ljk9_wq8d_.parquet")

# %%
print(df)
# Out:
#   id_equipamento            nome_equipamento             data_aquisicao  \
# 0        wnafrbp  Fermentadores para iogurte 2024-07-25 14:28:10.703293
#
#   eqp_status   eventType day month  year tenantId    eventId  ...  \
# 0     alerta  pressurize  25    12  2012     ljk9  ljk9_wq8d  ...
#
#   Prazo_Validade quantidade_estoque Nome_Funcionario     Cargo Departamento  \
# 0             26            13927.0    Jerome Little  Operador     Produção
#
#             Data_Contratacao Salario        Contato_Emergencia nome_setor  \
# 0 2024-07-25 14:28:10.703293  3423.6  Beth Spencer, 7937984958   producao
#
#   id_setor
# 0        1
#
# [1 rows x 35 columns]

# %%
table = pa.Table.from_pandas(df)

# %%
table.schema
# Out:
# id_equipamento: string
# nome_equipamento: string
# data_aquisicao: timestamp[ns]
# eqp_status: string
# eventType: string
# day: string
# month: string
# year: string
# tenantId: string
# eventId: string
# Nome_Fazenda: string
# Proprietario: string
# CNPJ_CPF: string
# Endereco: string
# Telefone: string
# Email: string
# Tipo_MateriaPrima: string
# Quantidade_Recebida: double
# Data_Recebimento: timestamp[ns]
# Qualidade: string
# Nome_Produto: string
# Categoria: string
# Descricao: string
# Unidade_Medida: string
# Preco_Unitario: double
# Prazo_Validade: int64
# quantidade_estoque: double
# Nome_Funcionario: string
# Cargo: string
# Departamento: string
# Data_Contratacao: timestamp[ns]
# Salario: double
# Contato_Emergencia: string
# nome_setor: string
# id_setor: int64
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 4556
